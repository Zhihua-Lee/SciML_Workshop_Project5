# %% [markdown]
# ## Quick data overview

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Loading data
x = np.load('x.npy') # x coordinates discretization vector

Nx = x.shape[0]
print("Num of discretization of x coordinates: ",Nx)

u0_train = np.load('u0_train_data.npy')
u0_test  = np.load('u0_test_data.npy')

Ntrain = u0_train.shape[0]
Ntest  = u0_test.shape[0]
print("Trainning data size:", Ntrain)
print("Testing data size:", Ntest)

u_train = np.load('u_train_data.npy')
u_test  = np.load('u_test_data.npy')
# Out:
# Num of discretization of x coordinates:  100
# Trainning data size: 2000
# Testing data size: 2000

# %%
# Plotting a few training samples
fig,axs = plt.subplots(2,2,figsize=(10,10))
axs = axs.flatten()
for s in range (4):
    axs[s].plot(x,u0_train[s],label='u(x,0)')
    axs[s].plot(x,u_train[s],label='u(x,T)')
    axs[s].legend()
# plt.savefig('result/samples.png',bbox_inches='tight')

# %% [markdown]
# ## Score-Based Conditional Diffusion Model

# %% [markdown]
# ### DM Architechture

# %%
#!/usr/bin/env python
# coding: utf-8

# # ==========================================================================================
# # Generic Conditional Score-Based Diffusion Model Module
# #
# # Description:
# # This script provides a self-contained, problem-agnostic implementation of a
# # conditional score-based diffusion model. It is designed to solve inverse problems
# # by learning the conditional score function s(x_t, y, t) directly from paired data (x, y),
# # as described in "Unifying and extending Diffusion Models through PDEs for solving
# # Inverse Problems" (arXiv:2504.07437).
# # ==========================================================================================

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import Adam
from torch.optim.lr_scheduler import CosineAnnealingLR, ReduceLROnPlateau 
from torch.utils.data import DataLoader, Dataset
import numpy as np
import functools
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm # this is for notebook and terminal
# from tqdm import tqdm # Use standard tqdm if notebook tqdm not available
from livelossplot import PlotLosses
import copy

class SimpleScaler:
    """A simple scaler that standardizes data to zero mean and unit variance."""
    def __init__(self):
        self.mean_ = None
        self.scale_ = None

    def fit(self, data):
        self.mean_ = np.mean(data, axis=0)
        self.scale_ = np.std(data, axis=0)
        # Handle cases where std dev is zero to avoid division by zero
        self.scale_[self.scale_ == 0] = 1.0
        return self

    def transform(self, data):
        if self.mean_ is None or self.scale_ is None:
            raise RuntimeError("Scaler has not been fitted yet.")
        return (data - self.mean_) / self.scale_

    def inverse_transform(self, data):
        if self.mean_ is None or self.scale_ is None:
            raise RuntimeError("Scaler has not been fitted yet.")
        return data * self.scale_ + self.mean_

    def get_state(self):
        return {'mean_': self.mean_, 'scale_': self.scale_}

    def load_state(self, state):
        self.mean_ = state['mean_']
        self.scale_ = state['scale_']
        return self
        
# --- 1. SDE and Time Embedding Definition (Problem-Agnostic) ---

class GaussianFourierProjection(nn.Module):
    """
    Encodes scalar time-steps into a high-dimensional feature vector
    using a set of fixed (non-trainable) random Fourier features.
    """
    def __init__(self, embed_dim, scale=30.):
        super().__init__()
        self.W = nn.Parameter(torch.randn(embed_dim // 2) * scale, requires_grad=False)

    def forward(self, t):
        t_proj = t[:, None] * self.W[None, :] * 2 * np.pi
        return torch.cat([torch.sin(t_proj), torch.cos(t_proj)], dim=-1)

def marginal_prob_std_fn(t, sigma):
    """
    Computes the standard deviation of p(x_t|x_0) for the VE-SDE.
    This corresponds to sigma_t in the notation p(x_t|x_0) = N(x_t; alpha_t*x_0, sigma_t^2*I).
    """
    t = torch.as_tensor(t)
    return torch.sqrt((sigma**(2 * t) - 1.) / (2. * np.log(sigma)))

def diffusion_coeff_fn(t, sigma):
    """Computes the diffusion coefficient g(t) for the VE-SDE."""
    t = torch.as_tensor(t)
    return sigma**t

# --- 2. Conditional Score Network (Problem-Agnostic) ---

class ConditionalScoreNet(nn.Module):
    """
    A time-dependent, conditional score-based model.
    It learns the score of the conditional distribution p_t(x|y), denoted as s(x, y, t).
    """
    def __init__(self, marginal_prob_std, x_dim, y_dim, hidden_depth=3, embed_dim=256):
        super().__init__()
        self.marginal_prob_std = marginal_prob_std
        
        # Time and condition embedding layers
        self.time_embed = nn.Sequential(
            GaussianFourierProjection(embed_dim=embed_dim),
            nn.Linear(embed_dim, embed_dim)
        )
        # A simple linear layer to embed the condition y
        self.condition_embed = nn.Linear(y_dim, embed_dim)
        
        # Main network layers
        self.input_layer = nn.Linear(x_dim, embed_dim)
        self.hidden_layers = nn.ModuleList([
            nn.Linear(embed_dim, embed_dim) for _ in range(hidden_depth)
        ])
        self.output_layer = nn.Linear(embed_dim, x_dim)
        
        self.act = nn.LeakyReLU(0.01)

    def forward(self, x, y, t):
        # 1. Generate embeddings for time and condition
        t_embedding = self.act(self.time_embed(t))
        y_embedding = self.act(self.condition_embed(y))
        
        # 2. Combine embeddings (simple addition)
        combined_embedding = t_embedding + y_embedding
        
        # 3. Process x through the network, modulated by the combined embedding
        h = self.act(self.input_layer(x))
        for layer in self.hidden_layers:
            # Add embedding and apply residual connection
            h = self.act(layer(h) + combined_embedding)
        
        out = self.output_layer(h)
        
        # 4. Scale output by the marginal standard deviation (a key part of the design)
        out = out / self.marginal_prob_std(t)[:, None]
        return out

class ConditionalConv1DScoreNet(nn.Module):
    """
    A time-dependent, conditional score-based model using a 1D U-Net architecture.
    It is specifically designed for function-like data where spatial correlation is important.
    It learns the score s(x, y, t).
    """
    def __init__(self, marginal_prob_std, x_dim, y_dim, hidden_depth=3, embed_dim=256):
        super().__init__()
        self.marginal_prob_std = marginal_prob_std
        
        # Time and condition embedding layers
        self.time_embed = nn.Sequential(
            GaussianFourierProjection(embed_dim=embed_dim),
            nn.Linear(embed_dim, embed_dim)
        )
        self.condition_embed = nn.Linear(y_dim, embed_dim)
        self.act = nn.LeakyReLU(0.01)

        # 1D U-Net Backbone
        # Encoder path
        kernel_size = 3
        padding = (kernel_size - 1) // 2 # This is robust, calculates to 1
        self.conv_in = nn.Conv1d(in_channels=1, out_channels=32, kernel_size=kernel_size, padding=padding) # Note: Input channel is now 1 (only x_t), as y is handled by embedding.
        self.conv1 = nn.Conv1d(32, 64, kernel_size=kernel_size, padding=padding)
        self.conv2 = nn.Conv1d(64, 128, kernel_size=kernel_size, padding=padding)
        
        # Bottleneck layer for time embedding injection
        self.embedding_injector = nn.Linear(embed_dim, 128)

        # Decoder path with skip connections
        self.deconv1 = nn.Conv1d(128 + 64, 64, kernel_size=kernel_size, padding=padding)
        self.deconv2 = nn.Conv1d(64 + 32, 32, kernel_size=kernel_size, padding=padding)
        self.conv_out = nn.Conv1d(32 , 1, kernel_size=kernel_size, padding=padding)
        
    def forward(self, x, y, t):
        # Reshape inputs to (Batch, Channels, Length) for Conv1d
        x = x.unsqueeze(1)
        # y is a vector, no need to unsqueeze, it will be used for embedding.

        # --- FIX: Correctly generate and combine embeddings for BOTH time and condition ---
        t_embedding = self.act(self.time_embed(t))
        y_embedding = self.act(self.condition_embed(y))
        combined_embedding = t_embedding + y_embedding
        
        # --- 1D U-Net Dataflow ---
        # Encoder
        # Note: Input is now just x, not the concatenation.
        h1 = self.act(self.conv_in(x))      # -> (B, 32, Length)
        h2 = self.act(self.conv1(h1))       # -> (B, 64, Length)
        h3 = self.act(self.conv2(h2))       # -> (B, 128, Length)

        # Inject COMBINED embedding at the bottleneck
        emb = self.embedding_injector(combined_embedding).unsqueeze(-1)
        h3_inj = h3 + emb # Broadcasts the embedding across the spatial dimension

        # Decoder with Skip Connections
        h_dec2_in = torch.cat([h3_inj, h2], dim=1)
        h_dec2 = self.act(self.deconv1(h_dec2_in))
        
        h_dec1_in = torch.cat([h_dec2, h1], dim=1)
        h_dec1 = self.act(self.deconv2(h_dec1_in))
        
        # The final input for the output convolution should not include the original x
        # as it's already part of the skip connection from h1
        out = self.conv_out(h_dec1) # Use h_dec1 directly
        
        # Reshape output back to (Batch, Length)
        out = out.squeeze(1)
        
        # Scale output by the marginal standard deviation
        out = out / self.marginal_prob_std(t)[:, None]
        return out

# --- 3. Loss Function (Problem-Agnostic) ---

def conditional_loss_fn(model, x, y, marginal_prob_std, eps=1e-5):
    """
    The loss function for training the conditional score model.
    Corresponds to the denoising score matching loss for p(x|y).
    with weighting to prioritize smaller noise levels.
    """
    # Sample random time steps
    random_t = torch.rand(x.shape[0], device=x.device) * (1. - eps) + eps
    
    # Sample noise and perturb data
    z = torch.randn_like(x)
    std = marginal_prob_std(random_t)
    perturbed_x = x + z * std[:, None]
    
    # Get model's score prediction
    score = model(perturbed_x, y, random_t)
    
    # # Calculate loss
    loss = torch.mean(torch.sum((score * std[:, None] + z)**2, dim=1))

    # Calculate the loss for each original sample.
    # loss_per_sample = torch.sum((score * std[:, None] + z)**2, dim=1)
    
    # # Define weights (using 1/std^2 here, other weights can also be tried)
    # # This weight amplifies the loss when t is small (std is small)
    # loss_weights = 1.0 / (std**2)
    
    # # Apply weights and calculate the mean.
    # loss = torch.mean(loss_weights * loss_per_sample)
    return loss

# --- 4. Training Infrastructure (Problem-Agnostic) ---

class PairedDataset(Dataset):
    """A dataset for (x, y) pairs."""
    def __init__(self, x_tensor, y_tensor):
        self.x = x_tensor
        self.y = y_tensor
    def __len__(self):
        return self.x.shape[0]
    def __getitem__(self, idx):
        return self.x[idx], self.y[idx]

def train_conditional_model(
    score_model,
    # Data
    x_train_data, y_train_data,
    x_test_data, y_test_data,
    # Training params
    lr=1e-4, batch_size=32, n_epochs=100,
    # Validation params
    eval_freq=25,
    num_eval_samples=50,
    num_gen_samples=10,
    # Control flags
    live_plot=True,
    # Sampler and other components
    sampler_fn=None,
    sampler_params=None,
    x_scaler=None,
    device='cpu'
):
    """
    Trains the model for the full duration, live-plots metrics, saves the best model
    based on generation_MSE, and returns the complete metric history.
    """
    # Setup DataLoaders for both training and validation
    train_dataset = PairedDataset(x_train_data.to(device), y_train_data.to(device))
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=0)
    
    test_dataset = PairedDataset(x_test_data.to(device), y_test_data.to(device))
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=0)

    optimizer = Adam(score_model.parameters(), lr=lr)
    scheduler = CosineAnnealingLR(optimizer, T_max=n_epochs) # Using a learning rate scheduler helps with better convergence in the later stages of training.
    # scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=400)
    
    # Use groups to plot losses and MSE on different axes, only initialize PlotLosses when needed.
    liveloss = PlotLosses(groups={'Log Loss': ['train_loss', 'val_loss'], 'Generation MSE': ['mse']}) if live_plot else None
    # --- History lists to store all metrics ---
    history = {'train_loss': [], 'val_loss': [], 'mse': []}
    best_mse = float('inf')
    best_model_state = None
    
    tqdm_epoch = tqdm(range(n_epochs), desc="Training Epochs", position=0, leave=True)
    for epoch in tqdm_epoch:
        # --- Training Phase ---
        score_model.train()
        train_loss = 0.
        num_items = 0
        for x_batch, y_batch in train_loader:
            loss = conditional_loss_fn(score_model, x_batch, y_batch, score_model.marginal_prob_std)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            train_loss += loss.item() * x_batch.shape[0]
            num_items += x_batch.shape[0]
        avg_train_loss = train_loss / num_items
        history['train_loss'].append(avg_train_loss)

        # --- Validation Phase ---
        score_model.eval()
        val_loss = 0.
        num_items_val = 0
        with torch.no_grad():
            for x_batch, y_batch in test_loader:
                loss = conditional_loss_fn(score_model, x_batch, y_batch, score_model.marginal_prob_std)
                val_loss += loss.item() * x_batch.shape[0]
                num_items_val += x_batch.shape[0]
        avg_val_loss = val_loss / num_items_val
        history['val_loss'].append(avg_val_loss)

        
        # --- Generation MSE Phase (run periodically to save time) ---
        avg_mse = np.nan # Default to NaN if not calculated this epoch
        if (epoch + 1) % eval_freq == 0 or (epoch == n_epochs - 1): # must compare at the last epoch
            with torch.no_grad():
                # (The generation logic is the same as below)
                total_mse = 0.
                # Randomly select indices from the test set for evaluation
                n_test = len(x_test_data)
                eval_indices = np.random.choice(n_test, num_eval_samples, replace=False)
                for i in eval_indices:
                    y_cond_scaled = y_test_data[i].unsqueeze(0)
                    x_true_unscaled_np = x_scaler.inverse_transform(x_test_data[i].cpu().numpy().reshape(1, -1)).flatten()
                    gen_samples_scaled = sampler_fn(score_model=score_model, y_cond=y_cond_scaled, batch_size=num_gen_samples, **sampler_params)
                    gen_samples_unscaled = x_scaler.inverse_transform(gen_samples_scaled.cpu().numpy())
                    gen_mean = np.mean(gen_samples_unscaled, axis=0)
                    total_mse += np.mean((gen_mean - x_true_unscaled_np)**2)
                avg_mse = total_mse / num_eval_samples

                if avg_mse < best_mse:
                    best_mse = avg_mse
                    best_model_state = copy.deepcopy(score_model.state_dict())
        
        history['mse'].append(avg_mse) # Append MSE or NaN to history
        
        if liveloss:
            logs = {'train_loss': avg_train_loss, 'val_loss': avg_val_loss}
            if not np.isnan(avg_mse): # Only add mse if it was calculated
                logs['mse'] = avg_mse
            liveloss.update(logs)
            # Only start sending (drawing) the plot AFTER the first MSE has been calculated.
            # This ensures the 'mse' key exists in the logger's history.
            if (epoch + 1) >= eval_freq:
                liveloss.send()
        else: # Print losses manually if live_plot is disabled
            msg = f"[Epoch {epoch+1:03d}] Train Loss: {avg_train_loss:.6f} | Val Loss: {avg_val_loss:.6f}"
            if not np.isnan(avg_mse):
                msg += f" | MSE: {avg_mse:.6f}"
            print(msg)
                
        # Update learning rate
        scheduler.step()
        # scheduler.step(avg_val_loss)  # For ReduceLROnPlateau; if using CosineAnnealingLR, use scheduler.step()


    if best_model_state:
        print(f"\nLoading best model with final generation_MSE: {best_mse:.4f}")
        score_model.load_state_dict(best_model_state)

    return score_model, history

# --- 5. Sampler (Problem-Agnostic) ---

def conditional_sampler(
    score_model,
    marginal_prob_std,
    diffusion_coeff,
    y_cond,
    batch_size,
    x_dim,
    num_steps=500,
    device='cpu',
    eps=1e-3
):
    """
    Generates samples from the conditional distribution p(x|y) using the trained score model.
    Implements the reverse-time SDE sampler (Euler-Maruyama method).
    """
    score_model.eval()
    t_init = torch.ones(batch_size, device=device)
    
    # Start from pure noise
    init_x = torch.randn(batch_size, x_dim, device=device) * marginal_prob_std(t_init)[:, None]
    
    time_steps = torch.linspace(1., eps, num_steps, device=device)
    step_size = time_steps[0] - time_steps[1]
    
    x = init_x
    y_cond_batch = y_cond.repeat(batch_size, 1).to(device)

    with torch.no_grad():
        # for time_step in tqdm(time_steps, desc="Conditional Sampling"):
        # for time_step in tqdm(time_steps, desc="Conditional Sampling", disable=not show_progress):
        sampler_iterator = tqdm(time_steps, desc="Conditional Sampling", position=1, leave=False)
        for time_step in sampler_iterator:
            batch_time_step = torch.ones(batch_size, device=device) * time_step
            g = diffusion_coeff(batch_time_step)
            
            # The core change: directly use the conditional score model
            score = score_model(x, y_cond_batch, batch_time_step)
            
            # Euler-Maruyama update
            mean_x = x + (g**2)[:, None] * score * step_size
            noise = torch.randn_like(x)
            x = mean_x + g[:, None] * torch.sqrt(step_size) * noise
            
    return mean_x

# %% [markdown]
# ### Training DM

# %%
# ==============================================================================
# PART 2: Main Script for Training the Conditional Diffusion Model
#
# Workflow:
# 1. Configuration: Set up all hyperparameters and flags.
# 2. Data Preparation: Load, filter, split, and normalize the dataset.
# 3. Model Initialization: Define the model and SDE functions based on configs.
# 4. Training Execution: Run the training process.
# 5. Results & Saving: Save the best model checkpoint and plot metrics.
# ==============================================================================


# --- 2.1 Configuration ---
# File Paths
MODEL_SAVE_PATH = 'best1_score_model_checkpoint2.pth'

# Data Splitting
validation_split = 0.2
random_seed = 42

# SDE Hyperparameters
SIGMA_VE = 25.0

# Model Hyperparameters
EMBED_DIM, HIDDEN_DEPTH = 1024, 4

# Training Hyperparameters
N_EPOCHS, BATCH_SIZE, LEARNING_RATE = 50000, 256, 2e-4

# Sampler Configuration
SAMPLER_NUM_STEPS = 500

NOISE_LEVEL = 0.50  # relative 5% componentwise

# --- 2.2 Setup Environment and Load Data ---
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

x_coords = np.load('x.npy')
u0_train_np_raw = np.load('u0_train_data.npy')
u_train_np_raw = np.load('u_train_data.npy')
u0_test_np_raw = np.load('u0_test_data.npy')
u_test_np_raw = np.load('u_test_data.npy')

# --- 2.3 Filter out zero-valued ground truth samples ---
print("\nFiltering dataset to keep only non-zero ground truth samples...")

# Filter training data
train_non_zero_indices = [idx for idx, sample in enumerate(u0_train_np_raw) if np.max(np.abs(sample)) > 1e-6]
u0_train_full_np = u0_train_np_raw[train_non_zero_indices]
u_train_full_np = u_train_np_raw[train_non_zero_indices]

# Filter testing data
test_non_zero_indices = [idx for idx, sample in enumerate(u0_test_np_raw) if np.max(np.abs(sample)) > 1e-6]
u0_test_np = u0_test_np_raw[test_non_zero_indices]
u_test_np = u_test_np_raw[test_non_zero_indices]

print(f"Original training size: {len(u0_train_np_raw)}, Filtered training size: {len(u0_train_full_np)}")
print(f"Original testing size: {len(u0_test_np_raw)}, Filtered testing size: {len(u0_test_np)}")

# ---Add Gaussian noise to each dimension 

# Compute std per dimension over all training samples (shape: (num_dims,))
y_train_std = np.std(u_train_full_np, axis=0)  # (num_dims,)
y_test_std = np.std(u_test_np, axis=0)  # (num_dims,)

# Add noise to training outputs only 
u_train_full_np = u_train_full_np + np.random.randn(*u_train_full_np.shape) * (NOISE_LEVEL * y_train_std) # *** uncomment to add noise
u_test_np = u_test_np + np.random.randn(*u_test_np.shape) * (NOISE_LEVEL * y_test_std)

# --- 2.4 Split the full training data into train and validation sets ---
print("\nSplitting training data into training and validation sets...")
# Create and shuffle indices
np.random.seed(random_seed)
num_train_full = len(u0_train_full_np)
indices = np.random.permutation(num_train_full)

# Determine the split point
split_idx = int(num_train_full * (1 - validation_split))

# Split indices
train_indices, val_indices = indices[:split_idx], indices[split_idx:]

# Create the data splits using the indices
u0_train_np, u0_val_np = u0_train_full_np[train_indices], u0_train_full_np[val_indices]
u_train_np, u_val_np = u_train_full_np[train_indices], u_train_full_np[val_indices]
print(f"Final training size: {len(u0_train_np)}, Validation size: {len(u0_val_np)}, Test size: {len(u0_test_np)}")

# --- 2.5 Get Data Dimensions ---
X_DIM, Y_DIM = u0_train_np.shape[1], u_train_np.shape[1]
print(f"\nProblem Dimensions: X_DIM = {X_DIM}, Y_DIM = {Y_DIM}")

# --- 2.6 Data Normalization and Tensor Conversion ---
print("\nNormalizing data...")
# Initialize and fit scalers ONLY on training data
x_scaler = SimpleScaler().fit(u0_train_np) 
y_scaler = SimpleScaler().fit(u_train_np)  

x_train_tensor = torch.from_numpy(x_scaler.transform(u0_train_np)).float()
y_train_tensor = torch.from_numpy(y_scaler.transform(u_train_np)).float()
x_val_tensor = torch.from_numpy(x_scaler.transform(u0_val_np)).float()
y_val_tensor = torch.from_numpy(y_scaler.transform(u_val_np)).float()

# --- 2.7 Initialize Model, SDE, and Sampler ---
# Define SDE functions
marginal_prob_std = functools.partial(marginal_prob_std_fn, sigma=SIGMA_VE)
diffusion_coeff = functools.partial(diffusion_coeff_fn, sigma=SIGMA_VE)

# Consolidate hyperparameter dictionaries for saving
model_hyperparams = {
    'x_dim': X_DIM, 'y_dim': Y_DIM,
    'embed_dim': EMBED_DIM, 'hidden_depth': HIDDEN_DEPTH
}
sde_hyperparams = {'sigma': SIGMA_VE}
sampler_params = { # Configure the sampler
    'marginal_prob_std': marginal_prob_std,
    'diffusion_coeff': diffusion_coeff,
    'x_dim': X_DIM,
    'num_steps': SAMPLER_NUM_STEPS,
    'device': device
}

# Initialize the Score Model
score_model = ConditionalScoreNet(
    marginal_prob_std, X_DIM, Y_DIM, HIDDEN_DEPTH, EMBED_DIM
).to(device)
# score_model = ConditionalConv1DScoreNet(
#     marginal_prob_std, X_DIM, Y_DIM, embed_dim=EMBED_DIM
# ).to(device)

# --- 2.8 Training Execution ---
print(f"\nStarting training for a new model with {sum(p.numel() for p in score_model.parameters())} parameters...")
score_model, history = train_conditional_model(
    score_model,
    x_train_data=x_train_tensor, y_train_data=y_train_tensor,
    x_test_data=x_val_tensor, y_test_data=y_val_tensor, # Use validation set for model selection
    lr=LEARNING_RATE, batch_size=BATCH_SIZE, n_epochs=N_EPOCHS,
    eval_freq=N_EPOCHS//8,
    live_plot=False, # Setting to False disables plotting and speeds up training.
    sampler_fn=conditional_sampler,
    sampler_params=sampler_params,
    x_scaler=x_scaler,
    device=device
)
print("Training finished.")

# --- 2.9 Save the Best Model and Plot Metrics ---
# --- Save the entire checkpoint ---
print(f"Saving the best model checkpoint to {MODEL_SAVE_PATH}...")
checkpoint = {
    'model_state_dict': score_model.state_dict(),
    'model_hyperparams': model_hyperparams,
    'sde_hyperparams': sde_hyperparams,
    'scaler_states': {
        'x_scaler': x_scaler.get_state(),
        'y_scaler': y_scaler.get_state()
    },
    'training_history': history
}
torch.save(checkpoint, MODEL_SAVE_PATH)
print("Checkpoint saved.")

fig_loss, ax1 = plt.subplots(figsize=(12, 7))

# Plotting training and validation loss on the first y-axis
ax1.plot(history['train_loss'], 'b-', label='Training Loss')
ax1.plot(history['val_loss'], 'c--', label='Validation Loss')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Score Matching Loss (log scale)', color='b')
ax1.set_yscale('log')
ax1.tick_params(axis='y', labelcolor='b')
ax1.grid(True, linestyle=':')

# Creating a second y-axis for the generation MSE
ax2 = ax1.twinx()
ax2.plot(history['mse'], 'r.-', label='Generation MSE')
ax2.set_ylabel('Generation MSE', color='r')
ax2.tick_params(axis='y', labelcolor='r')

fig_loss.suptitle('Training and Validation Metrics Over Epochs')
# Combining legends from both axes
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc='center right')

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
fig_loss.savefig('final_loss_curve2.png')
print("Metrics curve saved to 'final_loss_curve2.png'.")
# Out:
# Using device: cuda
#
# Filtering dataset to keep only non-zero ground truth samples...
# Original training size: 2000, Filtered training size: 2000
# Original testing size: 2000, Filtered testing size: 100
#
# Splitting training data into training and validation sets...
# Final training size: 1600, Validation size: 400, Test size: 100
#
# Problem Dimensions: X_DIM = 100, Y_DIM = 100
#
# Normalizing data...
#
# Starting training for a new model with 5557860 parameters...
# Training Epochs:   0%|          | 0/50000 [00:00<?, ?it/s]
# [Epoch 001] Train Loss: 107.115833 | Val Loss: 102.713735
# [Epoch 002] Train Loss: 101.874106 | Val Loss: 100.379155
# [Epoch 003] Train Loss: 99.981017 | Val Loss: 100.999419
# [Epoch 004] Train Loss: 99.095082 | Val Loss: 96.869864
# [Epoch 005] Train Loss: 96.815619 | Val Loss: 94.549693
# [Epoch 006] Train Loss: 92.133878 | Val Loss: 89.814540
# [Epoch 007] Train Loss: 87.820646 | Val Loss: 86.415938
# [Epoch 008] Train Loss: 82.432939 | Val Loss: 78.051269
# [Epoch 009] Train Loss: 79.008481 | Val Loss: 75.670078
# [Epoch 010] Train Loss: 74.417265 | Val Loss: 72.697609
# [Epoch 011] Train Loss: 70.903376 | Val Loss: 70.277946
# [Epoch 012] Train Loss: 67.742603 | Val Loss: 65.037538
# [Epoch 013] Train Loss: 65.276971 | Val Loss: 64.399151
# [Epoch 014] Train Loss: 63.076520 | Val Loss: 61.310916
# [Epoch 015] Train Loss: 59.385822 | Val Loss: 57.406832
# [Epoch 016] Train Loss: 56.545130 | Val Loss: 56.362029
# [Epoch 017] Train Loss: 54.664947 | Val Loss: 56.007929
# [Epoch 018] Train Loss: 54.040932 | Val Loss: 52.839953
# [Epoch 019] Train Loss: 52.860432 | Val Loss: 51.998785
# [Epoch 020] Train Loss: 49.599948 | Val Loss: 50.752163
# [Epoch 021] Train Loss: 48.717786 | Val Loss: 47.794258
# [Epoch 022] Train Loss: 47.057365 | Val Loss: 45.932610
# [Epoch 023] Train Loss: 46.590409 | Val Loss: 46.866096
# [Epoch 024] Train Loss: 45.922172 | Val Loss: 43.388889
# [Epoch 025] Train Loss: 43.399742 | Val Loss: 44.011100
# [Epoch 026] Train Loss: 42.587304 | Val Loss: 44.118299
# [Epoch 027] Train Loss: 41.835449 | Val Loss: 39.971815
# [Epoch 028] Train Loss: 39.787353 | Val Loss: 40.748144
# [Epoch 029] Train Loss: 39.514163 | Val Loss: 40.232506
# [Epoch 030] Train Loss: 37.430894 | Val Loss: 35.639337
# [Epoch 031] Train Loss: 36.531500 | Val Loss: 37.036355
# [Epoch 032] Train Loss: 36.665018 | Val Loss: 36.959861
# [Epoch 033] Train Loss: 35.774923 | Val Loss: 36.159953
# [Epoch 034] Train Loss: 33.982456 | Val Loss: 36.343128
# [Epoch 035] Train Loss: 34.460583 | Val Loss: 35.292989
# [Epoch 036] Train Loss: 31.035075 | Val Loss: 33.969997
# [Epoch 037] Train Loss: 31.262116 | Val Loss: 32.401777
# [Epoch 038] Train Loss: 31.081075 | Val Loss: 33.041553
# [Epoch 039] Train Loss: 30.000999 | Val Loss: 29.667209
# [Epoch 040] Train Loss: 30.295942 | Val Loss: 29.019315
# [Epoch 041] Train Loss: 29.313012 | Val Loss: 30.395175
# [Epoch 042] Train Loss: 28.325530 | Val Loss: 28.761853
# [Epoch 043] Train Loss: 27.809602 | Val Loss: 26.697450
# [Epoch 044] Train Loss: 27.074290 | Val Loss: 27.253045
# [Epoch 045] Train Loss: 26.644328 | Val Loss: 26.449447
# [Epoch 046] Train Loss: 27.320825 | Val Loss: 26.422853
# [Epoch 047] Train Loss: 27.043321 | Val Loss: 25.785034
# [Epoch 048] Train Loss: 26.070588 | Val Loss: 25.916309
# [Epoch 049] Train Loss: 25.886729 | Val Loss: 25.198753
# [Epoch 050] Train Loss: 25.769018 | Val Loss: 27.283509
# [Epoch 051] Train Loss: 25.626862 | Val Loss: 25.581594
# [Epoch 052] Train Loss: 24.329282 | Val Loss: 25.358937
# [Epoch 053] Train Loss: 25.191166 | Val Loss: 25.365213
# [Epoch 054] Train Loss: 24.398028 | Val Loss: 24.998823
# [Epoch 055] Train Loss: 23.935423 | Val Loss: 23.827843
# [Epoch 056] Train Loss: 23.912830 | Val Loss: 26.173590
# [Epoch 057] Train Loss: 23.520216 | Val Loss: 24.055013
# [Epoch 058] Train Loss: 23.338658 | Val Loss: 24.063323
# [Epoch 059] Train Loss: 23.053916 | Val Loss: 23.068902
# [Epoch 060] Train Loss: 23.651823 | Val Loss: 23.740776
# [Epoch 061] Train Loss: 23.095554 | Val Loss: 24.374672
# [Epoch 062] Train Loss: 22.877769 | Val Loss: 22.826390
# [Epoch 063] Train Loss: 22.767282 | Val Loss: 22.787580
# [Epoch 064] Train Loss: 22.948870 | Val Loss: 22.650566
# [Epoch 065] Train Loss: 22.038361 | Val Loss: 24.460501
# [Epoch 066] Train Loss: 21.587786 | Val Loss: 23.257197
# [Epoch 067] Train Loss: 22.057536 | Val Loss: 23.917982
# [Epoch 068] Train Loss: 21.661204 | Val Loss: 22.304732
# [Epoch 069] Train Loss: 22.861740 | Val Loss: 21.813690
# [Epoch 070] Train Loss: 21.992504 | Val Loss: 22.803873
# [Epoch 071] Train Loss: 21.514233 | Val Loss: 22.475533
# [Epoch 072] Train Loss: 22.066988 | Val Loss: 22.558633
# [Epoch 073] Train Loss: 21.639658 | Val Loss: 21.935341
# [Epoch 074] Train Loss: 21.701076 | Val Loss: 21.777603
# [Epoch 075] Train Loss: 21.497443 | Val Loss: 20.201192
# [Epoch 076] Train Loss: 21.309137 | Val Loss: 20.819839
# [Epoch 077] Train Loss: 20.361725 | Val Loss: 22.628585
# [Epoch 078] Train Loss: 20.208458 | Val Loss: 21.137726
# [Epoch 079] Train Loss: 20.598655 | Val Loss: 22.528395
# [Epoch 080] Train Loss: 19.699805 | Val Loss: 20.844180
# [Epoch 081] Train Loss: 20.474284 | Val Loss: 19.781545
# [Epoch 082] Train Loss: 20.636688 | Val Loss: 20.904540
# [Epoch 083] Train Loss: 19.827389 | Val Loss: 19.794474
# [Epoch 084] Train Loss: 20.059294 | Val Loss: 19.822638
# [Epoch 085] Train Loss: 20.097612 | Val Loss: 21.237558
# [Epoch 086] Train Loss: 20.154942 | Val Loss: 20.841444
# [Epoch 087] Train Loss: 19.996628 | Val Loss: 22.353040
# [Epoch 088] Train Loss: 20.440774 | Val Loss: 19.343532
# [Epoch 089] Train Loss: 19.837367 | Val Loss: 20.894290
# [Epoch 090] Train Loss: 19.641126 | Val Loss: 18.688923
# [Epoch 091] Train Loss: 20.183999 | Val Loss: 20.144144
# [Epoch 092] Train Loss: 20.106863 | Val Loss: 19.196322
# [Epoch 093] Train Loss: 20.137650 | Val Loss: 19.581419
# [Epoch 094] Train Loss: 19.563938 | Val Loss: 19.612281
# [Epoch 095] Train Loss: 18.993548 | Val Loss: 19.877103
# [Epoch 096] Train Loss: 18.798750 | Val Loss: 19.937206
# [Epoch 097] Train Loss: 18.657689 | Val Loss: 20.053648
# [Epoch 098] Train Loss: 18.816587 | Val Loss: 20.383387
# [Epoch 099] Train Loss: 18.709534 | Val Loss: 18.861090
# [Epoch 100] Train Loss: 20.057417 | Val Loss: 19.737807
# [Epoch 101] Train Loss: 18.380563 | Val Loss: 20.311161
# [Epoch 102] Train Loss: 18.064767 | Val Loss: 21.054563
# [Epoch 103] Train Loss: 18.929716 | Val Loss: 17.279614
# [Epoch 104] Train Loss: 18.623822 | Val Loss: 20.749235
# [Epoch 105] Train Loss: 18.674396 | Val Loss: 20.345828
# [Epoch 106] Train Loss: 17.997097 | Val Loss: 20.239672
# [Epoch 107] Train Loss: 18.832794 | Val Loss: 20.363997
# [Epoch 108] Train Loss: 18.706026 | Val Loss: 21.102395
# [Epoch 109] Train Loss: 18.844101 | Val Loss: 17.643191
# [Epoch 110] Train Loss: 17.718152 | Val Loss: 17.837313
# [Epoch 111] Train Loss: 17.835306 | Val Loss: 18.977514
# [Epoch 112] Train Loss: 18.659295 | Val Loss: 18.898732
# [Epoch 113] Train Loss: 17.860873 | Val Loss: 16.754462
# [Epoch 114] Train Loss: 17.429738 | Val Loss: 18.810373
# [Epoch 115] Train Loss: 18.214719 | Val Loss: 20.081348
# [Epoch 116] Train Loss: 17.674224 | Val Loss: 19.187607
# [Epoch 117] Train Loss: 17.150813 | Val Loss: 19.348668
# [Epoch 118] Train Loss: 17.916142 | Val Loss: 17.227675
# [Epoch 119] Train Loss: 17.249135 | Val Loss: 18.294816
# [Epoch 120] Train Loss: 17.147297 | Val Loss: 17.771703
# [Epoch 121] Train Loss: 17.398714 | Val Loss: 17.766169
# [Epoch 122] Train Loss: 17.314635 | Val Loss: 20.003630
# [Epoch 123] Train Loss: 17.675256 | Val Loss: 18.785859
# [Epoch 124] Train Loss: 17.078020 | Val Loss: 16.812479
# [Epoch 125] Train Loss: 16.311174 | Val Loss: 18.215458
# [Epoch 126] Train Loss: 17.173764 | Val Loss: 18.662919
# [Epoch 127] Train Loss: 16.641254 | Val Loss: 18.243610
# [Epoch 128] Train Loss: 16.841122 | Val Loss: 17.060292
# [Epoch 129] Train Loss: 16.508165 | Val Loss: 18.375162
# [Epoch 130] Train Loss: 17.183739 | Val Loss: 18.062252
# [Epoch 131] Train Loss: 16.215842 | Val Loss: 18.506431
# [Epoch 132] Train Loss: 16.851272 | Val Loss: 17.200441
# [Epoch 133] Train Loss: 17.470163 | Val Loss: 19.110791
# [Epoch 134] Train Loss: 17.374377 | Val Loss: 17.488231
# [Epoch 135] Train Loss: 16.468090 | Val Loss: 17.647599
# [Epoch 136] Train Loss: 17.408233 | Val Loss: 16.248410
# [Epoch 137] Train Loss: 17.378604 | Val Loss: 16.990697
# [Epoch 138] Train Loss: 17.118265 | Val Loss: 17.367186
# [Epoch 139] Train Loss: 16.003585 | Val Loss: 16.766636
# [Epoch 140] Train Loss: 16.486308 | Val Loss: 18.666754
# [Epoch 141] Train Loss: 16.857084 | Val Loss: 17.290435
# [Epoch 142] Train Loss: 16.090092 | Val Loss: 17.165520
# [Epoch 143] Train Loss: 16.016593 | Val Loss: 17.429327
# [Epoch 144] Train Loss: 16.197270 | Val Loss: 16.949396
# [Epoch 145] Train Loss: 16.705061 | Val Loss: 17.546831
# [Epoch 146] Train Loss: 16.626466 | Val Loss: 17.409359
# [Epoch 147] Train Loss: 16.645868 | Val Loss: 17.245342
# [Epoch 148] Train Loss: 16.973084 | Val Loss: 18.290810
# [Epoch 149] Train Loss: 16.532296 | Val Loss: 16.744194
# [Epoch 150] Train Loss: 15.342604 | Val Loss: 16.486115
# [Epoch 151] Train Loss: 16.122169 | Val Loss: 16.837847
# [Epoch 152] Train Loss: 16.729739 | Val Loss: 17.163539
# [Epoch 153] Train Loss: 16.491457 | Val Loss: 17.806919
# [Epoch 154] Train Loss: 16.682851 | Val Loss: 17.360801
# [Epoch 155] Train Loss: 16.142964 | Val Loss: 17.273595
# [Epoch 156] Train Loss: 15.872124 | Val Loss: 16.532785
# [Epoch 157] Train Loss: 15.308471 | Val Loss: 17.048423
# [Epoch 158] Train Loss: 16.287363 | Val Loss: 16.667285
# [Epoch 159] Train Loss: 15.736995 | Val Loss: 16.330260
# [Epoch 160] Train Loss: 15.810716 | Val Loss: 15.845871
# [Epoch 161] Train Loss: 16.202750 | Val Loss: 16.490126
# [Epoch 162] Train Loss: 15.361827 | Val Loss: 17.978655
# [Epoch 163] Train Loss: 15.781831 | Val Loss: 15.802433
# [Epoch 164] Train Loss: 15.077741 | Val Loss: 17.247060
# [Epoch 165] Train Loss: 15.268099 | Val Loss: 17.438667
# [Epoch 166] Train Loss: 15.607453 | Val Loss: 16.946368
# [Epoch 167] Train Loss: 15.987930 | Val Loss: 15.591785
# [Epoch 168] Train Loss: 15.119674 | Val Loss: 15.916955
# [Epoch 169] Train Loss: 14.631852 | Val Loss: 14.894829
# [Epoch 170] Train Loss: 14.372466 | Val Loss: 16.640882
# [Epoch 171] Train Loss: 15.262130 | Val Loss: 15.367695
# [Epoch 172] Train Loss: 15.122145 | Val Loss: 16.067558
# [Epoch 173] Train Loss: 14.910603 | Val Loss: 16.025119
# [Epoch 174] Train Loss: 15.146355 | Val Loss: 14.626766
# [Epoch 175] Train Loss: 14.951776 | Val Loss: 15.228342
# [Epoch 176] Train Loss: 14.997788 | Val Loss: 15.858357
# [Epoch 177] Train Loss: 14.735450 | Val Loss: 15.785965
# [Epoch 178] Train Loss: 15.352610 | Val Loss: 15.730341
# [Epoch 179] Train Loss: 15.030235 | Val Loss: 15.389519
# [Epoch 180] Train Loss: 14.746900 | Val Loss: 15.645995
# [Epoch 181] Train Loss: 14.664424 | Val Loss: 16.110503
# [Epoch 182] Train Loss: 14.495836 | Val Loss: 16.253038
# [Epoch 183] Train Loss: 14.473550 | Val Loss: 15.967464
# [Epoch 184] Train Loss: 14.890703 | Val Loss: 14.666963
# [Epoch 185] Train Loss: 14.843562 | Val Loss: 15.283049
# [Epoch 186] Train Loss: 14.731734 | Val Loss: 15.476905
# [Epoch 187] Train Loss: 14.592969 | Val Loss: 17.213456
# [Epoch 188] Train Loss: 14.971181 | Val Loss: 16.678920
# [Epoch 189] Train Loss: 14.619845 | Val Loss: 16.631286
# [Epoch 190] Train Loss: 14.997334 | Val Loss: 14.850131
# [Epoch 191] Train Loss: 14.825603 | Val Loss: 16.207753
# [Epoch 192] Train Loss: 15.002163 | Val Loss: 17.634758
# [Epoch 193] Train Loss: 14.656304 | Val Loss: 14.357709
# [Epoch 194] Train Loss: 14.781929 | Val Loss: 14.980746
# [Epoch 195] Train Loss: 14.762203 | Val Loss: 16.555094
# [Epoch 196] Train Loss: 14.360359 | Val Loss: 15.408987
# [Epoch 197] Train Loss: 14.603372 | Val Loss: 15.738663
# [Epoch 198] Train Loss: 15.023353 | Val Loss: 15.308059
# [Epoch 199] Train Loss: 13.943610 | Val Loss: 18.139856
# [Epoch 200] Train Loss: 14.568249 | Val Loss: 14.515150
# [Epoch 201] Train Loss: 15.082653 | Val Loss: 17.174913
# [Epoch 202] Train Loss: 14.294341 | Val Loss: 16.507644
# [Epoch 203] Train Loss: 13.835842 | Val Loss: 14.921067
# [Epoch 204] Train Loss: 13.849981 | Val Loss: 16.169753
# [Epoch 205] Train Loss: 14.441679 | Val Loss: 15.011571
# [Epoch 206] Train Loss: 14.532532 | Val Loss: 15.989088
# [Epoch 207] Train Loss: 13.987216 | Val Loss: 16.048799
# [Epoch 208] Train Loss: 14.085790 | Val Loss: 15.053361
# [Epoch 209] Train Loss: 13.739077 | Val Loss: 14.092504
# [Epoch 210] Train Loss: 13.890043 | Val Loss: 15.588969
# [Epoch 211] Train Loss: 13.729297 | Val Loss: 15.312038
# [Epoch 212] Train Loss: 14.100619 | Val Loss: 16.033834
# [Epoch 213] Train Loss: 13.554075 | Val Loss: 15.014722
# [Epoch 214] Train Loss: 14.203106 | Val Loss: 15.783720
# [Epoch 215] Train Loss: 13.848913 | Val Loss: 14.528061
# [Epoch 216] Train Loss: 14.073957 | Val Loss: 14.074683
# [Epoch 217] Train Loss: 14.593975 | Val Loss: 15.275624
# [Epoch 218] Train Loss: 13.828408 | Val Loss: 14.351274
# [Epoch 219] Train Loss: 14.072997 | Val Loss: 14.718712
# [Epoch 220] Train Loss: 14.224567 | Val Loss: 16.366179
# [Epoch 221] Train Loss: 14.581123 | Val Loss: 14.870553
# [Epoch 222] Train Loss: 13.932715 | Val Loss: 14.888287
# [Epoch 223] Train Loss: 14.289057 | Val Loss: 15.278838
# [Epoch 224] Train Loss: 13.440063 | Val Loss: 13.283797
# [Epoch 225] Train Loss: 13.317709 | Val Loss: 15.077571
# [Epoch 226] Train Loss: 13.360109 | Val Loss: 14.893229
# [Epoch 227] Train Loss: 13.509282 | Val Loss: 14.413010
# [Epoch 228] Train Loss: 13.414900 | Val Loss: 13.205902
# [Epoch 229] Train Loss: 13.742953 | Val Loss: 13.120090
# [Epoch 230] Train Loss: 13.466373 | Val Loss: 14.414453
# [Epoch 231] Train Loss: 13.363301 | Val Loss: 14.790630
# [Epoch 232] Train Loss: 13.897441 | Val Loss: 17.091489
# [Epoch 233] Train Loss: 13.729651 | Val Loss: 14.660552
# [Epoch 234] Train Loss: 13.612603 | Val Loss: 15.639775
# [Epoch 235] Train Loss: 13.255812 | Val Loss: 14.397819
# [Epoch 236] Train Loss: 13.127902 | Val Loss: 14.816705
# [Epoch 237] Train Loss: 13.714994 | Val Loss: 14.901273
# [Epoch 238] Train Loss: 13.626028 | Val Loss: 14.897692
# [Epoch 239] Train Loss: 13.453133 | Val Loss: 14.393342
# [Epoch 240] Train Loss: 12.971281 | Val Loss: 14.533846
# [Epoch 241] Train Loss: 13.551712 | Val Loss: 14.690466
# [Epoch 242] Train Loss: 12.861836 | Val Loss: 13.349283
# [Epoch 243] Train Loss: 13.221327 | Val Loss: 14.058434
# [Epoch 244] Train Loss: 12.710553 | Val Loss: 14.805546
# [Epoch 245] Train Loss: 13.865040 | Val Loss: 13.546464
# [Epoch 246] Train Loss: 14.161700 | Val Loss: 13.597128
# [Epoch 247] Train Loss: 13.757556 | Val Loss: 14.768159
# [Epoch 248] Train Loss: 12.744881 | Val Loss: 14.220457
# [Epoch 249] Train Loss: 13.457332 | Val Loss: 12.888395
# [Epoch 250] Train Loss: 13.372335 | Val Loss: 13.427188
# [Epoch 251] Train Loss: 12.712961 | Val Loss: 14.897086
# [Epoch 252] Train Loss: 13.397561 | Val Loss: 14.670150
# [Epoch 253] Train Loss: 13.030636 | Val Loss: 13.971187
# [Epoch 254] Train Loss: 13.349969 | Val Loss: 13.569343
# [Epoch 255] Train Loss: 13.228118 | Val Loss: 13.095958
# [Epoch 256] Train Loss: 12.341020 | Val Loss: 14.232580
# [Epoch 257] Train Loss: 13.299975 | Val Loss: 13.572011
# [Epoch 258] Train Loss: 12.768193 | Val Loss: 13.948790
# [Epoch 259] Train Loss: 13.315463 | Val Loss: 14.471005
# [Epoch 260] Train Loss: 13.002697 | Val Loss: 14.104019
# [Epoch 261] Train Loss: 12.439135 | Val Loss: 14.492428
# [Epoch 262] Train Loss: 13.596970 | Val Loss: 14.826663
# [Epoch 263] Train Loss: 13.327248 | Val Loss: 14.675198
# [Epoch 264] Train Loss: 13.100209 | Val Loss: 13.795428
# [Epoch 265] Train Loss: 13.227430 | Val Loss: 13.335082
# [Epoch 266] Train Loss: 12.339823 | Val Loss: 13.368218
# [Epoch 267] Train Loss: 12.746115 | Val Loss: 13.375819
# [Epoch 268] Train Loss: 12.820856 | Val Loss: 14.632814
# [Epoch 269] Train Loss: 12.590735 | Val Loss: 13.214805
# [Epoch 270] Train Loss: 12.878954 | Val Loss: 12.722777
# [Epoch 271] Train Loss: 13.138706 | Val Loss: 14.097582
# [Epoch 272] Train Loss: 12.680214 | Val Loss: 14.204321
# [Epoch 273] Train Loss: 12.823475 | Val Loss: 15.162661
# [Epoch 274] Train Loss: 12.346462 | Val Loss: 13.307671
# [Epoch 275] Train Loss: 12.888391 | Val Loss: 14.611399
# [Epoch 276] Train Loss: 12.579082 | Val Loss: 12.775504
# [Epoch 277] Train Loss: 12.819004 | Val Loss: 14.891780
# [Epoch 278] Train Loss: 13.170712 | Val Loss: 14.024304
# [Epoch 279] Train Loss: 12.851213 | Val Loss: 14.719688
# [Epoch 280] Train Loss: 12.179079 | Val Loss: 13.393852
# [Epoch 281] Train Loss: 13.064389 | Val Loss: 13.916525
# [Epoch 282] Train Loss: 12.360106 | Val Loss: 13.629145
# [Epoch 283] Train Loss: 11.446174 | Val Loss: 14.748962
# [Epoch 284] Train Loss: 12.507163 | Val Loss: 13.170534
# [Epoch 285] Train Loss: 12.192046 | Val Loss: 13.147936
# [Epoch 286] Train Loss: 12.064646 | Val Loss: 14.357409
# [Epoch 287] Train Loss: 12.271083 | Val Loss: 13.926769
# [Epoch 288] Train Loss: 13.444028 | Val Loss: 13.028818
# [Epoch 289] Train Loss: 12.188092 | Val Loss: 12.389239
# [Epoch 290] Train Loss: 12.598277 | Val Loss: 13.519024
# [Epoch 291] Train Loss: 12.232340 | Val Loss: 12.819838
# [Epoch 292] Train Loss: 12.577606 | Val Loss: 13.443463
# [Epoch 293] Train Loss: 12.457535 | Val Loss: 14.384196
# [Epoch 294] Train Loss: 12.194993 | Val Loss: 13.034373
# [Epoch 295] Train Loss: 12.501592 | Val Loss: 13.991388
# [Epoch 296] Train Loss: 12.427171 | Val Loss: 12.852307
# [Epoch 297] Train Loss: 12.577925 | Val Loss: 12.948404
# [Epoch 298] Train Loss: 12.021209 | Val Loss: 13.753123
# [Epoch 299] Train Loss: 12.010654 | Val Loss: 13.059548
# [Epoch 300] Train Loss: 12.210770 | Val Loss: 15.069451
# [Epoch 301] Train Loss: 11.869391 | Val Loss: 14.776993
# [Epoch 302] Train Loss: 12.602551 | Val Loss: 13.231948
# [Epoch 303] Train Loss: 12.599045 | Val Loss: 13.435835
# [Epoch 304] Train Loss: 12.024535 | Val Loss: 13.574341
# [Epoch 305] Train Loss: 12.127158 | Val Loss: 13.826272
# [Epoch 306] Train Loss: 11.858376 | Val Loss: 13.609035
# [Epoch 307] Train Loss: 11.935267 | Val Loss: 12.968277
# [Epoch 308] Train Loss: 11.433426 | Val Loss: 13.504435
# [Epoch 309] Train Loss: 11.986123 | Val Loss: 13.087803
# [Epoch 310] Train Loss: 11.749352 | Val Loss: 13.820024
# [Epoch 311] Train Loss: 11.780869 | Val Loss: 12.587044
# [Epoch 312] Train Loss: 11.787569 | Val Loss: 12.526308
# [Epoch 313] Train Loss: 12.028816 | Val Loss: 13.545772
# [Epoch 314] Train Loss: 12.521890 | Val Loss: 13.421266
# [Epoch 315] Train Loss: 12.111264 | Val Loss: 14.048707
# [Epoch 316] Train Loss: 11.701455 | Val Loss: 13.028624
# [Epoch 317] Train Loss: 12.079360 | Val Loss: 13.402539
# [Epoch 318] Train Loss: 12.210853 | Val Loss: 13.176503
# [Epoch 319] Train Loss: 11.971494 | Val Loss: 13.591691
# [Epoch 320] Train Loss: 12.579522 | Val Loss: 13.602895
# [Epoch 321] Train Loss: 11.596615 | Val Loss: 13.158305
# [Epoch 322] Train Loss: 12.242286 | Val Loss: 13.447761
# [Epoch 323] Train Loss: 12.072401 | Val Loss: 13.571722
# [Epoch 324] Train Loss: 11.536424 | Val Loss: 13.544184
# [Epoch 325] Train Loss: 11.619179 | Val Loss: 12.605856
# [Epoch 326] Train Loss: 12.232234 | Val Loss: 13.275899
# [Epoch 327] Train Loss: 11.630292 | Val Loss: 12.693459
# [Epoch 328] Train Loss: 11.993778 | Val Loss: 12.368948
# [Epoch 329] Train Loss: 12.254668 | Val Loss: 13.758301
# [Epoch 330] Train Loss: 12.107067 | Val Loss: 13.536367
# [Epoch 331] Train Loss: 11.241576 | Val Loss: 12.128070
# [Epoch 332] Train Loss: 12.401066 | Val Loss: 14.340204
# [Epoch 333] Train Loss: 12.065661 | Val Loss: 13.147762
# [Epoch 334] Train Loss: 11.355936 | Val Loss: 12.695182
# [Epoch 335] Train Loss: 11.666419 | Val Loss: 13.094937
# [Epoch 336] Train Loss: 12.173397 | Val Loss: 13.294048
# [Epoch 337] Train Loss: 12.105742 | Val Loss: 13.151639
# [Epoch 338] Train Loss: 11.542794 | Val Loss: 12.475646
# [Epoch 339] Train Loss: 11.578294 | Val Loss: 13.219146
# [Epoch 340] Train Loss: 11.733562 | Val Loss: 11.978613
# [Epoch 341] Train Loss: 12.113266 | Val Loss: 13.768812
# [Epoch 342] Train Loss: 11.698695 | Val Loss: 13.390660
# [Epoch 343] Train Loss: 11.349632 | Val Loss: 12.442558
# [Epoch 344] Train Loss: 11.440046 | Val Loss: 12.514444
# [Epoch 345] Train Loss: 11.745380 | Val Loss: 12.652199
# [Epoch 346] Train Loss: 11.202067 | Val Loss: 13.638015
# [Epoch 347] Train Loss: 11.960331 | Val Loss: 13.021765
# [Epoch 348] Train Loss: 11.679725 | Val Loss: 12.802522
# [Epoch 349] Train Loss: 11.198188 | Val Loss: 12.516532
# [Epoch 350] Train Loss: 11.899777 | Val Loss: 12.950747
# [Epoch 351] Train Loss: 11.763050 | Val Loss: 13.801456
# [Epoch 352] Train Loss: 11.632531 | Val Loss: 13.306155
# [Epoch 353] Train Loss: 11.360805 | Val Loss: 12.325300
# [Epoch 354] Train Loss: 11.580111 | Val Loss: 12.825338
# [Epoch 355] Train Loss: 11.721084 | Val Loss: 13.494668
# [Epoch 356] Train Loss: 11.383603 | Val Loss: 12.933554
# [Epoch 357] Train Loss: 11.291737 | Val Loss: 11.832208
# [Epoch 358] Train Loss: 11.187454 | Val Loss: 12.688275
# [Epoch 359] Train Loss: 11.105322 | Val Loss: 12.326387
# [Epoch 360] Train Loss: 11.023118 | Val Loss: 12.113833
# [Epoch 361] Train Loss: 10.749385 | Val Loss: 11.754811
# [Epoch 362] Train Loss: 10.838174 | Val Loss: 12.403739
# [Epoch 363] Train Loss: 11.085840 | Val Loss: 12.573467
# [Epoch 364] Train Loss: 11.206722 | Val Loss: 12.271197
# [Epoch 365] Train Loss: 11.875790 | Val Loss: 13.017966
# [Epoch 366] Train Loss: 11.085178 | Val Loss: 14.232011
# [Epoch 367] Train Loss: 11.278972 | Val Loss: 11.183503
# [Epoch 368] Train Loss: 11.189782 | Val Loss: 13.327485
# [Epoch 369] Train Loss: 12.023897 | Val Loss: 11.375018
# [Epoch 370] Train Loss: 10.726670 | Val Loss: 12.878690
# [Epoch 371] Train Loss: 10.885351 | Val Loss: 12.179747
# [Epoch 372] Train Loss: 11.275235 | Val Loss: 12.613627
# [Epoch 373] Train Loss: 10.934355 | Val Loss: 12.885000
# [Epoch 374] Train Loss: 11.491015 | Val Loss: 12.208413
# [Epoch 375] Train Loss: 10.923187 | Val Loss: 12.844718
# [Epoch 376] Train Loss: 10.939698 | Val Loss: 12.380319
# [Epoch 377] Train Loss: 10.551453 | Val Loss: 12.445147
# [Epoch 378] Train Loss: 11.193375 | Val Loss: 12.919633
# [Epoch 379] Train Loss: 11.249509 | Val Loss: 13.169061
# [Epoch 380] Train Loss: 11.229387 | Val Loss: 13.365334
# [Epoch 381] Train Loss: 10.704805 | Val Loss: 11.858955
# [Epoch 382] Train Loss: 11.043581 | Val Loss: 12.053669
# [Epoch 383] Train Loss: 11.409552 | Val Loss: 12.126670
# [Epoch 384] Train Loss: 10.908272 | Val Loss: 12.919288
# [Epoch 385] Train Loss: 10.753845 | Val Loss: 11.317093
# [Epoch 386] Train Loss: 10.888442 | Val Loss: 12.394884
# [Epoch 387] Train Loss: 10.726544 | Val Loss: 12.953600
# [Epoch 388] Train Loss: 10.656588 | Val Loss: 12.929926
# [Epoch 389] Train Loss: 11.236421 | Val Loss: 12.333855
# [Epoch 390] Train Loss: 11.623527 | Val Loss: 13.001232
# [Epoch 391] Train Loss: 10.774548 | Val Loss: 12.898865
# [Epoch 392] Train Loss: 11.562471 | Val Loss: 14.110169
# [Epoch 393] Train Loss: 11.154827 | Val Loss: 13.078049
# [Epoch 394] Train Loss: 11.154727 | Val Loss: 11.185093
# [Epoch 395] Train Loss: 10.788531 | Val Loss: 12.478140
# [Epoch 396] Train Loss: 11.073483 | Val Loss: 11.948905
# [Epoch 397] Train Loss: 11.556206 | Val Loss: 11.620520
# [Epoch 398] Train Loss: 10.419192 | Val Loss: 12.498384
# [Epoch 399] Train Loss: 11.071619 | Val Loss: 11.266720
# [Epoch 400] Train Loss: 10.683496 | Val Loss: 11.037319
# [Epoch 401] Train Loss: 10.825643 | Val Loss: 12.436870
# [Epoch 402] Train Loss: 10.981891 | Val Loss: 12.896150
# [Epoch 403] Train Loss: 10.509691 | Val Loss: 12.639555
# [Epoch 404] Train Loss: 10.758362 | Val Loss: 12.164915
# [Epoch 405] Train Loss: 10.113269 | Val Loss: 12.514451
# [Epoch 406] Train Loss: 10.217327 | Val Loss: 12.002515
# [Epoch 407] Train Loss: 10.453434 | Val Loss: 12.275766
# [Epoch 408] Train Loss: 10.552467 | Val Loss: 10.803043
# [Epoch 409] Train Loss: 10.661174 | Val Loss: 11.759665
# [Epoch 410] Train Loss: 10.464649 | Val Loss: 12.033238
# [Epoch 411] Train Loss: 11.027502 | Val Loss: 12.494392
# [Epoch 412] Train Loss: 10.990730 | Val Loss: 13.550686
# [Epoch 413] Train Loss: 10.868200 | Val Loss: 12.182288
# [Epoch 414] Train Loss: 10.827130 | Val Loss: 11.338033
# [Epoch 415] Train Loss: 10.236175 | Val Loss: 12.252289
# [Epoch 416] Train Loss: 11.233096 | Val Loss: 12.315000
# [Epoch 417] Train Loss: 11.811162 | Val Loss: 11.871226
# [Epoch 418] Train Loss: 10.440477 | Val Loss: 11.557680
# [Epoch 419] Train Loss: 10.833392 | Val Loss: 12.041422
# [Epoch 420] Train Loss: 11.302121 | Val Loss: 11.594502
# [Epoch 421] Train Loss: 10.792307 | Val Loss: 12.551205
# [Epoch 422] Train Loss: 10.473613 | Val Loss: 11.998279
# [Epoch 423] Train Loss: 10.998051 | Val Loss: 11.854963
# [Epoch 424] Train Loss: 10.427458 | Val Loss: 11.384936
# [Epoch 425] Train Loss: 10.502198 | Val Loss: 12.331661
# [Epoch 426] Train Loss: 10.544357 | Val Loss: 11.925508
# [Epoch 427] Train Loss: 10.861917 | Val Loss: 11.869937
# [Epoch 428] Train Loss: 10.925730 | Val Loss: 11.737012
# [Epoch 429] Train Loss: 11.283685 | Val Loss: 11.033366
# [Epoch 430] Train Loss: 10.515054 | Val Loss: 13.088813
# [Epoch 431] Train Loss: 10.740780 | Val Loss: 11.987656
# [Epoch 432] Train Loss: 10.405393 | Val Loss: 11.521856
# [Epoch 433] Train Loss: 10.188282 | Val Loss: 12.001281
# [Epoch 434] Train Loss: 10.438368 | Val Loss: 12.464646
# [Epoch 435] Train Loss: 10.197187 | Val Loss: 12.421473
# [Epoch 436] Train Loss: 10.931192 | Val Loss: 10.677216
# [Epoch 437] Train Loss: 10.386654 | Val Loss: 11.756574
# [Epoch 438] Train Loss: 11.054543 | Val Loss: 13.521704
# [Epoch 439] Train Loss: 10.779154 | Val Loss: 12.457841
# [Epoch 440] Train Loss: 10.736883 | Val Loss: 12.639348
# [Epoch 441] Train Loss: 10.142276 | Val Loss: 10.633621
# [Epoch 442] Train Loss: 10.446784 | Val Loss: 10.459490
# [Epoch 443] Train Loss: 9.714511 | Val Loss: 11.734339
# [Epoch 444] Train Loss: 10.340303 | Val Loss: 12.143563
# [Epoch 445] Train Loss: 10.413063 | Val Loss: 11.909236
# [Epoch 446] Train Loss: 10.295198 | Val Loss: 12.497016
# [Epoch 447] Train Loss: 10.338769 | Val Loss: 11.313489
# [Epoch 448] Train Loss: 10.197668 | Val Loss: 11.966443
# [Epoch 449] Train Loss: 10.435344 | Val Loss: 11.794335
# [Epoch 450] Train Loss: 10.069431 | Val Loss: 11.830503
# [Epoch 451] Train Loss: 10.734886 | Val Loss: 11.649176
# [Epoch 452] Train Loss: 10.510909 | Val Loss: 11.823158
# [Epoch 453] Train Loss: 10.861131 | Val Loss: 11.395654
# [Epoch 454] Train Loss: 10.625306 | Val Loss: 11.460354
# [Epoch 455] Train Loss: 10.225922 | Val Loss: 12.384690
# [Epoch 456] Train Loss: 10.331645 | Val Loss: 12.525255
# [Epoch 457] Train Loss: 10.154240 | Val Loss: 11.552119
# [Epoch 458] Train Loss: 10.193159 | Val Loss: 11.953414
# [Epoch 459] Train Loss: 10.349726 | Val Loss: 11.376737
# [Epoch 460] Train Loss: 10.276291 | Val Loss: 11.141766
# [Epoch 461] Train Loss: 10.248730 | Val Loss: 11.873690
# [Epoch 462] Train Loss: 10.482652 | Val Loss: 10.761562
# [Epoch 463] Train Loss: 9.743647 | Val Loss: 11.657949
# [Epoch 464] Train Loss: 10.371509 | Val Loss: 11.511901
# [Epoch 465] Train Loss: 10.687807 | Val Loss: 11.965210
# [Epoch 466] Train Loss: 10.178685 | Val Loss: 11.455543
# [Epoch 467] Train Loss: 9.658466 | Val Loss: 11.499714
# [Epoch 468] Train Loss: 10.445521 | Val Loss: 10.750665
# [Epoch 469] Train Loss: 10.120380 | Val Loss: 11.760604
# [Epoch 470] Train Loss: 10.200751 | Val Loss: 12.081348
# [Epoch 471] Train Loss: 10.109120 | Val Loss: 11.064679
# [Epoch 472] Train Loss: 10.053726 | Val Loss: 11.825719
# [Epoch 473] Train Loss: 10.184352 | Val Loss: 11.909115
# [Epoch 474] Train Loss: 9.789025 | Val Loss: 12.161138
# [Epoch 475] Train Loss: 10.375327 | Val Loss: 11.068454
# [Epoch 476] Train Loss: 10.391346 | Val Loss: 11.761650
# [Epoch 477] Train Loss: 9.905711 | Val Loss: 11.896616
# [Epoch 478] Train Loss: 10.343028 | Val Loss: 11.661507
# [Epoch 479] Train Loss: 9.927765 | Val Loss: 11.335391
# [Epoch 480] Train Loss: 10.042118 | Val Loss: 11.093982
# [Epoch 481] Train Loss: 10.029057 | Val Loss: 11.728437
# [Epoch 482] Train Loss: 9.924717 | Val Loss: 12.512138
# [Epoch 483] Train Loss: 9.526702 | Val Loss: 12.494611
# [Epoch 484] Train Loss: 9.995742 | Val Loss: 11.173332
# [Epoch 485] Train Loss: 10.037044 | Val Loss: 12.486577
# [Epoch 486] Train Loss: 10.009502 | Val Loss: 11.323293
# [Epoch 487] Train Loss: 9.762079 | Val Loss: 12.005515
# [Epoch 488] Train Loss: 9.950407 | Val Loss: 10.796708
# [Epoch 489] Train Loss: 9.935865 | Val Loss: 11.914922
# [Epoch 490] Train Loss: 9.932095 | Val Loss: 12.528580
# [Epoch 491] Train Loss: 9.749923 | Val Loss: 11.542252
# [Epoch 492] Train Loss: 9.917896 | Val Loss: 10.595174
# [Epoch 493] Train Loss: 10.004049 | Val Loss: 12.406741
# [Epoch 494] Train Loss: 10.327709 | Val Loss: 11.641553
# [Epoch 495] Train Loss: 10.256776 | Val Loss: 12.409761
# [Epoch 496] Train Loss: 10.097225 | Val Loss: 12.001934
# [Epoch 497] Train Loss: 10.030028 | Val Loss: 10.169884
# [Epoch 498] Train Loss: 10.161572 | Val Loss: 10.256628
# [Epoch 499] Train Loss: 9.938831 | Val Loss: 11.758919
# [Epoch 500] Train Loss: 10.151216 | Val Loss: 10.678260
# [Epoch 501] Train Loss: 9.853143 | Val Loss: 10.993726
# [Epoch 502] Train Loss: 10.072303 | Val Loss: 11.782258
# [Epoch 503] Train Loss: 9.996288 | Val Loss: 11.226235
# [Epoch 504] Train Loss: 9.888656 | Val Loss: 10.460498
# [Epoch 505] Train Loss: 9.744613 | Val Loss: 12.140289
# [Epoch 506] Train Loss: 9.698128 | Val Loss: 11.932571
# [Epoch 507] Train Loss: 9.647402 | Val Loss: 11.604468
# [Epoch 508] Train Loss: 9.970928 | Val Loss: 10.570448
# [Epoch 509] Train Loss: 9.866381 | Val Loss: 11.726120
# [Epoch 510] Train Loss: 9.897648 | Val Loss: 11.459607
# [Epoch 511] Train Loss: 10.097378 | Val Loss: 11.960056
# [Epoch 512] Train Loss: 9.517342 | Val Loss: 10.232322
# [Epoch 513] Train Loss: 9.809685 | Val Loss: 10.741679
# [Epoch 514] Train Loss: 9.890053 | Val Loss: 10.669810
# [Epoch 515] Train Loss: 9.793951 | Val Loss: 10.946343
# [Epoch 516] Train Loss: 9.647164 | Val Loss: 10.756386
# [Epoch 517] Train Loss: 9.573535 | Val Loss: 11.460127
# [Epoch 518] Train Loss: 9.817432 | Val Loss: 11.659414
# [Epoch 519] Train Loss: 9.794146 | Val Loss: 11.866145
# [Epoch 520] Train Loss: 9.827624 | Val Loss: 11.499014
# [Epoch 521] Train Loss: 9.585032 | Val Loss: 13.058053
# [Epoch 522] Train Loss: 9.986418 | Val Loss: 11.497433
# [Epoch 523] Train Loss: 9.700048 | Val Loss: 12.048500
# [Epoch 524] Train Loss: 9.938287 | Val Loss: 11.740532
# [Epoch 525] Train Loss: 9.544275 | Val Loss: 11.219696
# [Epoch 526] Train Loss: 9.653864 | Val Loss: 11.169556
# [Epoch 527] Train Loss: 9.264450 | Val Loss: 11.272868
# [Epoch 528] Train Loss: 9.639869 | Val Loss: 10.955225
# [Epoch 529] Train Loss: 10.074870 | Val Loss: 10.760445
# [Epoch 530] Train Loss: 9.565379 | Val Loss: 11.115551
# [Epoch 531] Train Loss: 9.436354 | Val Loss: 10.854893
# [Epoch 532] Train Loss: 9.343400 | Val Loss: 11.342757
# [Epoch 533] Train Loss: 9.420500 | Val Loss: 12.066142
# [Epoch 534] Train Loss: 9.319234 | Val Loss: 11.949839
# [Epoch 535] Train Loss: 9.621554 | Val Loss: 12.255525
# [Epoch 536] Train Loss: 9.808248 | Val Loss: 11.357908
# [Epoch 537] Train Loss: 10.074043 | Val Loss: 11.704077
# [Epoch 538] Train Loss: 9.652660 | Val Loss: 11.175004
# [Epoch 539] Train Loss: 9.867984 | Val Loss: 10.597527
# [Epoch 540] Train Loss: 10.042666 | Val Loss: 10.578846
# [Epoch 541] Train Loss: 9.973056 | Val Loss: 11.081252
# [Epoch 542] Train Loss: 9.056240 | Val Loss: 11.139741
# [Epoch 543] Train Loss: 9.410690 | Val Loss: 11.072563
# [Epoch 544] Train Loss: 9.286750 | Val Loss: 11.211530
# [Epoch 545] Train Loss: 9.575837 | Val Loss: 10.737460
# [Epoch 546] Train Loss: 9.380795 | Val Loss: 9.718295
# [Epoch 547] Train Loss: 9.534481 | Val Loss: 11.203704
# [Epoch 548] Train Loss: 9.333614 | Val Loss: 10.762775
# [Epoch 549] Train Loss: 9.494775 | Val Loss: 10.586947
# [Epoch 550] Train Loss: 9.165520 | Val Loss: 11.473248
# [Epoch 551] Train Loss: 9.481857 | Val Loss: 10.231382
# [Epoch 552] Train Loss: 9.661684 | Val Loss: 10.375736
# [Epoch 553] Train Loss: 9.884831 | Val Loss: 12.056772
# [Epoch 554] Train Loss: 9.304627 | Val Loss: 11.141295
# [Epoch 555] Train Loss: 9.865511 | Val Loss: 11.873947
# [Epoch 556] Train Loss: 9.912711 | Val Loss: 10.617911
# [Epoch 557] Train Loss: 9.643072 | Val Loss: 10.673577
# [Epoch 558] Train Loss: 9.683286 | Val Loss: 10.404822
# [Epoch 559] Train Loss: 9.517881 | Val Loss: 11.799064
# [Epoch 560] Train Loss: 9.255678 | Val Loss: 11.362242
# [Epoch 561] Train Loss: 9.470712 | Val Loss: 11.938890
# [Epoch 562] Train Loss: 9.423237 | Val Loss: 11.141149
# [Epoch 563] Train Loss: 9.155481 | Val Loss: 11.906229
# [Epoch 564] Train Loss: 9.480357 | Val Loss: 10.975473
# [Epoch 565] Train Loss: 9.581639 | Val Loss: 11.272451
# [Epoch 566] Train Loss: 9.502685 | Val Loss: 10.111325
# [Epoch 567] Train Loss: 9.402450 | Val Loss: 9.544719
# [Epoch 568] Train Loss: 9.344004 | Val Loss: 10.271818
# [Epoch 569] Train Loss: 9.174380 | Val Loss: 11.184550
# [Epoch 570] Train Loss: 9.653041 | Val Loss: 10.544735
# [Epoch 571] Train Loss: 9.793322 | Val Loss: 10.445553
# [Epoch 572] Train Loss: 9.232430 | Val Loss: 9.600470
# [Epoch 573] Train Loss: 9.412835 | Val Loss: 11.189088
# [Epoch 574] Train Loss: 9.910182 | Val Loss: 10.762352
# [Epoch 575] Train Loss: 9.428723 | Val Loss: 10.857329
# [Epoch 576] Train Loss: 9.783617 | Val Loss: 10.099542
# [Epoch 577] Train Loss: 9.895737 | Val Loss: 10.789714
# [Epoch 578] Train Loss: 9.676293 | Val Loss: 10.712624
# [Epoch 579] Train Loss: 9.214276 | Val Loss: 10.945459
# [Epoch 580] Train Loss: 9.009111 | Val Loss: 11.954480
# [Epoch 581] Train Loss: 9.355877 | Val Loss: 10.215735
# [Epoch 582] Train Loss: 9.230633 | Val Loss: 11.128281
# [Epoch 583] Train Loss: 9.787104 | Val Loss: 10.471415
# [Epoch 584] Train Loss: 9.552477 | Val Loss: 9.665195
# [Epoch 585] Train Loss: 9.118569 | Val Loss: 10.521130
# [Epoch 586] Train Loss: 9.105359 | Val Loss: 9.940243
# [Epoch 587] Train Loss: 9.071615 | Val Loss: 10.790629
# [Epoch 588] Train Loss: 9.192784 | Val Loss: 10.793312
# [Epoch 589] Train Loss: 8.994025 | Val Loss: 11.073485
# [Epoch 590] Train Loss: 9.244720 | Val Loss: 10.552217
# [Epoch 591] Train Loss: 9.341821 | Val Loss: 11.553625
# [Epoch 592] Train Loss: 9.091700 | Val Loss: 11.141331
# [Epoch 593] Train Loss: 9.160440 | Val Loss: 10.926576
# [Epoch 594] Train Loss: 9.489835 | Val Loss: 10.677412
# [Epoch 595] Train Loss: 9.264703 | Val Loss: 11.046949
# [Epoch 596] Train Loss: 9.464957 | Val Loss: 11.256329
# [Epoch 597] Train Loss: 9.397428 | Val Loss: 11.543252
# [Epoch 598] Train Loss: 9.034412 | Val Loss: 10.598720
# [Epoch 599] Train Loss: 9.677912 | Val Loss: 10.328193
# [Epoch 600] Train Loss: 9.372674 | Val Loss: 12.033939
# [Epoch 601] Train Loss: 9.640448 | Val Loss: 11.080769
# [Epoch 602] Train Loss: 9.663621 | Val Loss: 9.872926
# [Epoch 603] Train Loss: 9.062435 | Val Loss: 10.759249
# [Epoch 604] Train Loss: 9.391299 | Val Loss: 10.663616
# [Epoch 605] Train Loss: 9.519022 | Val Loss: 9.179171
# [Epoch 606] Train Loss: 9.037977 | Val Loss: 10.401256
# [Epoch 607] Train Loss: 8.634260 | Val Loss: 10.408558
# [Epoch 608] Train Loss: 9.089718 | Val Loss: 10.443951
# [Epoch 609] Train Loss: 8.640141 | Val Loss: 10.450860
# [Epoch 610] Train Loss: 9.214944 | Val Loss: 10.324117
# [Epoch 611] Train Loss: 9.178029 | Val Loss: 10.842865
# [Epoch 612] Train Loss: 8.878544 | Val Loss: 11.359462
# [Epoch 613] Train Loss: 9.121409 | Val Loss: 9.439515
# [Epoch 614] Train Loss: 9.005594 | Val Loss: 10.459858
# [Epoch 615] Train Loss: 9.180183 | Val Loss: 11.016863
# [Epoch 616] Train Loss: 8.919932 | Val Loss: 10.425921
# [Epoch 617] Train Loss: 9.262260 | Val Loss: 10.740532
# [Epoch 618] Train Loss: 9.145026 | Val Loss: 9.905228
# [Epoch 619] Train Loss: 9.255770 | Val Loss: 10.373722
# [Epoch 620] Train Loss: 8.874874 | Val Loss: 10.641635
# [Epoch 621] Train Loss: 8.836376 | Val Loss: 11.122943
# [Epoch 622] Train Loss: 9.182720 | Val Loss: 10.195439
# [Epoch 623] Train Loss: 9.359824 | Val Loss: 10.894087
# [Epoch 624] Train Loss: 9.314827 | Val Loss: 11.157685
# [Epoch 625] Train Loss: 9.007297 | Val Loss: 11.166042
# [Epoch 626] Train Loss: 9.126147 | Val Loss: 9.717359
# [Epoch 627] Train Loss: 9.183171 | Val Loss: 11.123668
# [Epoch 628] Train Loss: 9.197291 | Val Loss: 11.857956
# [Epoch 629] Train Loss: 8.702369 | Val Loss: 11.190677
# [Epoch 630] Train Loss: 9.762120 | Val Loss: 10.682069
# [Epoch 631] Train Loss: 9.482772 | Val Loss: 10.576504
# [Epoch 632] Train Loss: 9.559104 | Val Loss: 11.313818
# [Epoch 633] Train Loss: 9.238104 | Val Loss: 10.691897
# [Epoch 634] Train Loss: 9.721516 | Val Loss: 10.291152
# [Epoch 635] Train Loss: 9.248452 | Val Loss: 9.537111
# [Epoch 636] Train Loss: 8.856327 | Val Loss: 9.696672
# [Epoch 637] Train Loss: 9.040405 | Val Loss: 11.254353
# [Epoch 638] Train Loss: 9.057468 | Val Loss: 10.695063
# [Epoch 639] Train Loss: 8.728011 | Val Loss: 10.007232
# [Epoch 640] Train Loss: 8.661642 | Val Loss: 10.581143
# [Epoch 641] Train Loss: 9.162162 | Val Loss: 10.385043
# [Epoch 642] Train Loss: 8.770360 | Val Loss: 10.378688
# [Epoch 643] Train Loss: 8.983415 | Val Loss: 9.966208
# [Epoch 644] Train Loss: 8.929400 | Val Loss: 11.210233
# [Epoch 645] Train Loss: 9.021724 | Val Loss: 11.163123
# [Epoch 646] Train Loss: 8.934135 | Val Loss: 10.338875
# [Epoch 647] Train Loss: 8.746891 | Val Loss: 10.656789
# [Epoch 648] Train Loss: 8.604618 | Val Loss: 10.527686
# [Epoch 649] Train Loss: 8.722434 | Val Loss: 10.262655
# [Epoch 650] Train Loss: 8.889547 | Val Loss: 10.836135
# [Epoch 651] Train Loss: 8.698747 | Val Loss: 10.625086
# [Epoch 652] Train Loss: 8.782833 | Val Loss: 10.243970
# [Epoch 653] Train Loss: 9.296764 | Val Loss: 10.266339
# [Epoch 654] Train Loss: 9.087483 | Val Loss: 11.182002
# [Epoch 655] Train Loss: 8.461564 | Val Loss: 10.639538
# [Epoch 656] Train Loss: 8.710597 | Val Loss: 10.892945
# [Epoch 657] Train Loss: 9.052573 | Val Loss: 10.770451
# [Epoch 658] Train Loss: 8.916491 | Val Loss: 10.814205
# [Epoch 659] Train Loss: 8.784717 | Val Loss: 10.419368
# [Epoch 660] Train Loss: 9.048770 | Val Loss: 10.118569
# [Epoch 661] Train Loss: 9.188180 | Val Loss: 10.021848
# [Epoch 662] Train Loss: 9.444891 | Val Loss: 10.874856
# [Epoch 663] Train Loss: 8.796333 | Val Loss: 10.029442
# [Epoch 664] Train Loss: 9.123042 | Val Loss: 10.046594
# [Epoch 665] Train Loss: 8.613219 | Val Loss: 9.563524
# [Epoch 666] Train Loss: 9.214019 | Val Loss: 10.053140
# [Epoch 667] Train Loss: 8.865344 | Val Loss: 10.172083
# [Epoch 668] Train Loss: 8.856268 | Val Loss: 10.653698
# [Epoch 669] Train Loss: 8.430736 | Val Loss: 11.178825
# [Epoch 670] Train Loss: 8.526036 | Val Loss: 10.480572
# [Epoch 671] Train Loss: 9.016590 | Val Loss: 10.894594
# [Epoch 672] Train Loss: 9.184114 | Val Loss: 9.299995
# [Epoch 673] Train Loss: 8.744205 | Val Loss: 10.107577
# [Epoch 674] Train Loss: 8.547665 | Val Loss: 10.834272
# [Epoch 675] Train Loss: 8.457973 | Val Loss: 10.652355
# [Epoch 676] Train Loss: 9.162723 | Val Loss: 10.763989
# [Epoch 677] Train Loss: 9.165052 | Val Loss: 10.868163
# [Epoch 678] Train Loss: 8.735483 | Val Loss: 11.109963
# [Epoch 679] Train Loss: 8.617203 | Val Loss: 9.531375
# [Epoch 680] Train Loss: 9.014521 | Val Loss: 9.587825
# [Epoch 681] Train Loss: 9.079482 | Val Loss: 10.658316
# [Epoch 682] Train Loss: 9.107266 | Val Loss: 9.803373
# [Epoch 683] Train Loss: 8.830673 | Val Loss: 11.149402
# [Epoch 684] Train Loss: 8.836606 | Val Loss: 9.253090
# [Epoch 685] Train Loss: 8.298464 | Val Loss: 10.576191
# [Epoch 686] Train Loss: 8.447252 | Val Loss: 10.084767
# [Epoch 687] Train Loss: 8.621946 | Val Loss: 12.394804
# [Epoch 688] Train Loss: 8.695382 | Val Loss: 9.714263
# [Epoch 689] Train Loss: 8.901542 | Val Loss: 10.299409
# [Epoch 690] Train Loss: 8.754223 | Val Loss: 9.333643
# [Epoch 691] Train Loss: 8.635836 | Val Loss: 11.041126
# [Epoch 692] Train Loss: 8.661716 | Val Loss: 11.458789
# [Epoch 693] Train Loss: 8.848722 | Val Loss: 11.294744
# [Epoch 694] Train Loss: 8.865778 | Val Loss: 10.259011
# [Epoch 695] Train Loss: 8.828690 | Val Loss: 10.038998
# [Epoch 696] Train Loss: 8.774719 | Val Loss: 9.627512
# [Epoch 697] Train Loss: 8.609549 | Val Loss: 10.242784
# [Epoch 698] Train Loss: 8.992425 | Val Loss: 10.118141
# [Epoch 699] Train Loss: 8.633536 | Val Loss: 10.935032
# [Epoch 700] Train Loss: 8.536182 | Val Loss: 10.142579
# [Epoch 701] Train Loss: 8.994003 | Val Loss: 10.958503
# [Epoch 702] Train Loss: 8.857172 | Val Loss: 10.868316
# [Epoch 703] Train Loss: 8.327153 | Val Loss: 10.731004
# [Epoch 704] Train Loss: 8.625192 | Val Loss: 10.164475
# [Epoch 705] Train Loss: 8.161772 | Val Loss: 9.755724
# [Epoch 706] Train Loss: 8.699028 | Val Loss: 10.284900
# [Epoch 707] Train Loss: 8.564541 | Val Loss: 9.443451
# [Epoch 708] Train Loss: 8.975942 | Val Loss: 10.222768
# [Epoch 709] Train Loss: 8.453831 | Val Loss: 10.246723
# [Epoch 710] Train Loss: 8.446523 | Val Loss: 10.295514
# [Epoch 711] Train Loss: 8.493169 | Val Loss: 9.492019
# [Epoch 712] Train Loss: 8.502916 | Val Loss: 9.652322
# [Epoch 713] Train Loss: 8.498154 | Val Loss: 10.361585
# [Epoch 714] Train Loss: 8.317702 | Val Loss: 10.130159
# [Epoch 715] Train Loss: 8.210514 | Val Loss: 10.199351
# [Epoch 716] Train Loss: 8.514263 | Val Loss: 11.178933
# [Epoch 717] Train Loss: 9.052464 | Val Loss: 10.462671
# [Epoch 718] Train Loss: 8.237053 | Val Loss: 9.616520
# [Epoch 719] Train Loss: 8.537113 | Val Loss: 9.535275
# [Epoch 720] Train Loss: 9.097401 | Val Loss: 11.236786
# [Epoch 721] Train Loss: 8.744902 | Val Loss: 10.466898
# [Epoch 722] Train Loss: 8.677739 | Val Loss: 10.151877
# [Epoch 723] Train Loss: 8.769873 | Val Loss: 9.885413
# [Epoch 724] Train Loss: 8.595915 | Val Loss: 10.046003
# [Epoch 725] Train Loss: 8.755173 | Val Loss: 11.074935
# [Epoch 726] Train Loss: 8.482630 | Val Loss: 10.085634
# [Epoch 727] Train Loss: 8.458002 | Val Loss: 9.837962
# [Epoch 728] Train Loss: 8.672484 | Val Loss: 10.842761
# [Epoch 729] Train Loss: 8.322580 | Val Loss: 9.758847
# [Epoch 730] Train Loss: 8.535757 | Val Loss: 10.003464
# [Epoch 731] Train Loss: 8.642994 | Val Loss: 11.662679
# [Epoch 732] Train Loss: 8.215907 | Val Loss: 9.121828
# [Epoch 733] Train Loss: 8.691311 | Val Loss: 10.026940
# [Epoch 734] Train Loss: 8.766323 | Val Loss: 9.679436
# [Epoch 735] Train Loss: 8.412922 | Val Loss: 10.556740
# [Epoch 736] Train Loss: 8.271554 | Val Loss: 10.096650
# [Epoch 737] Train Loss: 8.006705 | Val Loss: 9.376181
# [Epoch 738] Train Loss: 8.204129 | Val Loss: 9.765717
# [Epoch 739] Train Loss: 8.357136 | Val Loss: 10.308846
# [Epoch 740] Train Loss: 8.296012 | Val Loss: 9.683799
# [Epoch 741] Train Loss: 8.098860 | Val Loss: 10.094130
# [Epoch 742] Train Loss: 8.083743 | Val Loss: 9.249547
# [Epoch 743] Train Loss: 8.462750 | Val Loss: 10.039989
# [Epoch 744] Train Loss: 8.601827 | Val Loss: 9.115745
# [Epoch 745] Train Loss: 8.396557 | Val Loss: 11.299839
# [Epoch 746] Train Loss: 8.041842 | Val Loss: 10.081375
# [Epoch 747] Train Loss: 7.896738 | Val Loss: 9.331988
# [Epoch 748] Train Loss: 8.373622 | Val Loss: 9.012394
# [Epoch 749] Train Loss: 8.455268 | Val Loss: 10.787907
# [Epoch 750] Train Loss: 8.829784 | Val Loss: 9.653738
# [Epoch 751] Train Loss: 8.430485 | Val Loss: 8.699639
# [Epoch 752] Train Loss: 8.314471 | Val Loss: 9.560315
# [Epoch 753] Train Loss: 8.135992 | Val Loss: 10.612494
# [Epoch 754] Train Loss: 8.441232 | Val Loss: 10.061872
# [Epoch 755] Train Loss: 8.101419 | Val Loss: 9.427324
# [Epoch 756] Train Loss: 8.483101 | Val Loss: 9.901426
# [Epoch 757] Train Loss: 8.248883 | Val Loss: 9.973035
# [Epoch 758] Train Loss: 8.482407 | Val Loss: 10.729752
# [Epoch 759] Train Loss: 8.744415 | Val Loss: 10.483090
# [Epoch 760] Train Loss: 8.293915 | Val Loss: 10.152291
# [Epoch 761] Train Loss: 7.949504 | Val Loss: 10.058639
# [Epoch 762] Train Loss: 8.417100 | Val Loss: 9.657017
# [Epoch 763] Train Loss: 7.963222 | Val Loss: 10.413677
# [Epoch 764] Train Loss: 8.060193 | Val Loss: 10.088866
# [Epoch 765] Train Loss: 7.939946 | Val Loss: 9.757522
# [Epoch 766] Train Loss: 8.294215 | Val Loss: 10.116660
# [Epoch 767] Train Loss: 8.470454 | Val Loss: 10.258665
# [Epoch 768] Train Loss: 7.984854 | Val Loss: 9.124433
# [Epoch 769] Train Loss: 8.094278 | Val Loss: 9.580602
# [Epoch 770] Train Loss: 8.439226 | Val Loss: 9.227120
# [Epoch 771] Train Loss: 8.343885 | Val Loss: 9.427750
# [Epoch 772] Train Loss: 7.800973 | Val Loss: 9.657143
# [Epoch 773] Train Loss: 8.165566 | Val Loss: 9.580231
# [Epoch 774] Train Loss: 7.979684 | Val Loss: 10.101862
# [Epoch 775] Train Loss: 8.481936 | Val Loss: 10.483581
# [Epoch 776] Train Loss: 8.317488 | Val Loss: 9.509616
# [Epoch 777] Train Loss: 8.140222 | Val Loss: 9.298268
# [Epoch 778] Train Loss: 8.029461 | Val Loss: 10.891445
# [Epoch 779] Train Loss: 8.198577 | Val Loss: 10.712778
# [Epoch 780] Train Loss: 8.223467 | Val Loss: 10.244414
# [Epoch 781] Train Loss: 8.518285 | Val Loss: 10.681237
# [Epoch 782] Train Loss: 8.682813 | Val Loss: 9.669573
# [Epoch 783] Train Loss: 8.375010 | Val Loss: 9.236166
# [Epoch 784] Train Loss: 8.039368 | Val Loss: 9.588300
# [Epoch 785] Train Loss: 8.133431 | Val Loss: 9.298686
# [Epoch 786] Train Loss: 8.279334 | Val Loss: 9.927825
# [Epoch 787] Train Loss: 8.593777 | Val Loss: 9.960583
# [Epoch 788] Train Loss: 8.168063 | Val Loss: 9.924821
# [Epoch 789] Train Loss: 8.518736 | Val Loss: 10.538283
# [Epoch 790] Train Loss: 8.124040 | Val Loss: 9.727407
# [Epoch 791] Train Loss: 7.853482 | Val Loss: 9.306418
# [Epoch 792] Train Loss: 8.179113 | Val Loss: 10.162190
# [Epoch 793] Train Loss: 8.207263 | Val Loss: 9.948372
# [Epoch 794] Train Loss: 8.308216 | Val Loss: 10.317466
# [Epoch 795] Train Loss: 8.470253 | Val Loss: 10.056805
# [Epoch 796] Train Loss: 8.199604 | Val Loss: 10.907996
# [Epoch 797] Train Loss: 8.615085 | Val Loss: 9.479213
# [Epoch 798] Train Loss: 8.238111 | Val Loss: 10.120058
# [Epoch 799] Train Loss: 8.230794 | Val Loss: 9.072116
# [Epoch 800] Train Loss: 8.439738 | Val Loss: 10.395903
# [Epoch 801] Train Loss: 8.153372 | Val Loss: 9.758735
# [Epoch 802] Train Loss: 8.418390 | Val Loss: 9.636196
# [Epoch 803] Train Loss: 8.244116 | Val Loss: 9.291562
# [Epoch 804] Train Loss: 8.032259 | Val Loss: 10.030874
# [Epoch 805] Train Loss: 7.899556 | Val Loss: 9.234181
# [Epoch 806] Train Loss: 8.068335 | Val Loss: 10.536283
# [Epoch 807] Train Loss: 8.452757 | Val Loss: 9.904953
# [Epoch 808] Train Loss: 8.399173 | Val Loss: 9.293060
# [Epoch 809] Train Loss: 8.367888 | Val Loss: 9.856344
# [Epoch 810] Train Loss: 8.192357 | Val Loss: 9.452856
# [Epoch 811] Train Loss: 8.747644 | Val Loss: 9.631816
# [Epoch 812] Train Loss: 8.429328 | Val Loss: 10.009158
# [Epoch 813] Train Loss: 8.079445 | Val Loss: 10.069081
# [Epoch 814] Train Loss: 8.235312 | Val Loss: 9.741435
# [Epoch 815] Train Loss: 7.884677 | Val Loss: 10.055995
# [Epoch 816] Train Loss: 8.276677 | Val Loss: 8.818830
# [Epoch 817] Train Loss: 7.830857 | Val Loss: 9.367229
# [Epoch 818] Train Loss: 8.600186 | Val Loss: 8.799569
# [Epoch 819] Train Loss: 8.147804 | Val Loss: 10.146493
# [Epoch 820] Train Loss: 8.197069 | Val Loss: 10.097678
# [Epoch 821] Train Loss: 8.193092 | Val Loss: 9.617904
# [Epoch 822] Train Loss: 8.057467 | Val Loss: 10.035665
# [Epoch 823] Train Loss: 8.366907 | Val Loss: 8.453144
# [Epoch 824] Train Loss: 7.974174 | Val Loss: 8.850396
# [Epoch 825] Train Loss: 8.014269 | Val Loss: 9.483373
# [Epoch 826] Train Loss: 7.911134 | Val Loss: 10.217222
# [Epoch 827] Train Loss: 8.346486 | Val Loss: 10.189424
# [Epoch 828] Train Loss: 8.522696 | Val Loss: 9.916655
# [Epoch 829] Train Loss: 7.883336 | Val Loss: 9.467066
# [Epoch 830] Train Loss: 7.835591 | Val Loss: 9.783334
# [Epoch 831] Train Loss: 7.863373 | Val Loss: 9.161625
# [Epoch 832] Train Loss: 8.164694 | Val Loss: 10.519255
# [Epoch 833] Train Loss: 8.196317 | Val Loss: 10.634807
# [Epoch 834] Train Loss: 7.990130 | Val Loss: 10.060592
# [Epoch 835] Train Loss: 7.719028 | Val Loss: 10.228810
# [Epoch 836] Train Loss: 7.995357 | Val Loss: 9.343898
# [Epoch 837] Train Loss: 7.699261 | Val Loss: 9.791345
# [Epoch 838] Train Loss: 7.756848 | Val Loss: 9.702034
# [Epoch 839] Train Loss: 7.948691 | Val Loss: 10.591498
# [Epoch 840] Train Loss: 8.123354 | Val Loss: 8.487323
# [Epoch 841] Train Loss: 8.019601 | Val Loss: 10.584302
# [Epoch 842] Train Loss: 8.507648 | Val Loss: 8.968277
# [Epoch 843] Train Loss: 8.030900 | Val Loss: 10.540503
# [Epoch 844] Train Loss: 8.083283 | Val Loss: 8.776285
# [Epoch 845] Train Loss: 7.985051 | Val Loss: 10.408002
# [Epoch 846] Train Loss: 8.250774 | Val Loss: 9.429749
# [Epoch 847] Train Loss: 7.988634 | Val Loss: 10.313511
# [Epoch 848] Train Loss: 7.812724 | Val Loss: 9.809840
# [Epoch 849] Train Loss: 7.488358 | Val Loss: 9.393130
# [Epoch 850] Train Loss: 7.766447 | Val Loss: 9.336775
# [Epoch 851] Train Loss: 7.860173 | Val Loss: 9.294200
# [Epoch 852] Train Loss: 7.750084 | Val Loss: 10.378260
# [Epoch 853] Train Loss: 7.934250 | Val Loss: 9.316283
# [Epoch 854] Train Loss: 7.740116 | Val Loss: 10.092435
# [Epoch 855] Train Loss: 7.617457 | Val Loss: 9.616078
# [Epoch 856] Train Loss: 8.132851 | Val Loss: 10.118663
# ...
# [Epoch 28456] Train Loss: 0.830267 | Val Loss: 7.607787
# [Epoch 28457] Train Loss: 0.906391 | Val Loss: 9.605628
# [Epoch 28458] Train Loss: 0.825725 | Val Loss: 11.899808
# [Epoch 28459] Train Loss: 0.794449 | Val Loss: 10.017324
# [Epoch 28460] Train Loss: 0.747675 | Val Loss: 9.954104
# [Epoch 28461] Train Loss: 0.726357 | Val Loss: 10.596425
# [Epoch 28462] Train Loss: 0.720528 | Val Loss: 10.871955
# [Epoch 28463] Train Loss: 0.766314 | Val Loss: 10.802801
# [Epoch 28464] Train Loss: 0.898023 | Val Loss: 12.084150
# [Epoch 28465] Train Loss: 1.041520 | Val Loss: 10.526740
# [Epoch 28466] Train Loss: 0.920093 | Val Loss: 9.560370
# [Epoch 28467] Train Loss: 0.987445 | Val Loss: 10.812748
# [Epoch 28468] Train Loss: 0.836477 | Val Loss: 8.838262
# [Epoch 28469] Train Loss: 0.837275 | Val Loss: 9.793000
# [Epoch 28470] Train Loss: 0.728496 | Val Loss: 11.327083
# [Epoch 28471] Train Loss: 0.786209 | Val Loss: 10.887724
# [Epoch 28472] Train Loss: 0.775352 | Val Loss: 8.851125
# [Epoch 28473] Train Loss: 0.767394 | Val Loss: 9.471890
# [Epoch 28474] Train Loss: 0.770398 | Val Loss: 12.837145
# [Epoch 28475] Train Loss: 0.856201 | Val Loss: 10.128078
# [Epoch 28476] Train Loss: 0.775658 | Val Loss: 11.538388
# [Epoch 28477] Train Loss: 0.866637 | Val Loss: 9.834811
# [Epoch 28478] Train Loss: 0.771016 | Val Loss: 9.975826
# [Epoch 28479] Train Loss: 0.725922 | Val Loss: 10.823169
# [Epoch 28480] Train Loss: 0.708999 | Val Loss: 11.963283
# [Epoch 28481] Train Loss: 0.755962 | Val Loss: 11.124702
# [Epoch 28482] Train Loss: 0.845048 | Val Loss: 11.795490
# [Epoch 28483] Train Loss: 0.917536 | Val Loss: 11.769334
# [Epoch 28484] Train Loss: 0.827165 | Val Loss: 9.669637
# [Epoch 28485] Train Loss: 0.763631 | Val Loss: 9.674683
# [Epoch 28486] Train Loss: 0.739913 | Val Loss: 11.498599
# [Epoch 28487] Train Loss: 0.779306 | Val Loss: 12.446155
# [Epoch 28488] Train Loss: 0.840019 | Val Loss: 10.371462
# [Epoch 28489] Train Loss: 0.861456 | Val Loss: 10.576395
# [Epoch 28490] Train Loss: 0.816185 | Val Loss: 8.666660
# [Epoch 28491] Train Loss: 0.897107 | Val Loss: 11.842010
# [Epoch 28492] Train Loss: 0.727167 | Val Loss: 10.111412
# [Epoch 28493] Train Loss: 0.747900 | Val Loss: 11.441633
# [Epoch 28494] Train Loss: 0.800708 | Val Loss: 9.120586
# [Epoch 28495] Train Loss: 0.767747 | Val Loss: 8.604634
# [Epoch 28496] Train Loss: 0.736928 | Val Loss: 10.944721
# [Epoch 28497] Train Loss: 0.952639 | Val Loss: 10.741357
# [Epoch 28498] Train Loss: 0.969757 | Val Loss: 13.935972
# [Epoch 28499] Train Loss: 0.987311 | Val Loss: 11.831963
# [Epoch 28500] Train Loss: 0.910338 | Val Loss: 10.000460
# [Epoch 28501] Train Loss: 0.771791 | Val Loss: 11.314340
# [Epoch 28502] Train Loss: 0.761553 | Val Loss: 10.735779
# [Epoch 28503] Train Loss: 0.755563 | Val Loss: 9.204560
# [Epoch 28504] Train Loss: 0.833944 | Val Loss: 10.596443
# [Epoch 28505] Train Loss: 0.872417 | Val Loss: 11.167100
# [Epoch 28506] Train Loss: 0.858047 | Val Loss: 9.578462
# [Epoch 28507] Train Loss: 0.839285 | Val Loss: 11.038199
# [Epoch 28508] Train Loss: 0.834888 | Val Loss: 11.268205
# [Epoch 28509] Train Loss: 0.911750 | Val Loss: 12.242125
# [Epoch 28510] Train Loss: 0.798523 | Val Loss: 12.808303
# [Epoch 28511] Train Loss: 0.786216 | Val Loss: 8.791424
# [Epoch 28512] Train Loss: 0.752820 | Val Loss: 11.175709
# [Epoch 28513] Train Loss: 0.700740 | Val Loss: 9.802172
# [Epoch 28514] Train Loss: 0.717692 | Val Loss: 9.147383
# [Epoch 28515] Train Loss: 0.782358 | Val Loss: 10.425229
# [Epoch 28516] Train Loss: 0.935560 | Val Loss: 9.005645
# [Epoch 28517] Train Loss: 0.815538 | Val Loss: 9.077070
# [Epoch 28518] Train Loss: 0.781525 | Val Loss: 11.693315
# [Epoch 28519] Train Loss: 0.834268 | Val Loss: 8.522486
# [Epoch 28520] Train Loss: 0.838853 | Val Loss: 10.332077
# [Epoch 28521] Train Loss: 0.882331 | Val Loss: 10.131146
# [Epoch 28522] Train Loss: 0.747431 | Val Loss: 11.648570
# [Epoch 28523] Train Loss: 0.763889 | Val Loss: 11.727299
# [Epoch 28524] Train Loss: 0.697101 | Val Loss: 10.838448
# [Epoch 28525] Train Loss: 0.761267 | Val Loss: 7.997178
# [Epoch 28526] Train Loss: 0.825912 | Val Loss: 8.281746
# [Epoch 28527] Train Loss: 0.872767 | Val Loss: 9.507410
# [Epoch 28528] Train Loss: 0.808260 | Val Loss: 9.045126
# [Epoch 28529] Train Loss: 0.773869 | Val Loss: 8.582150
# [Epoch 28530] Train Loss: 0.747820 | Val Loss: 11.647230
# [Epoch 28531] Train Loss: 0.768447 | Val Loss: 8.215254
# [Epoch 28532] Train Loss: 0.748837 | Val Loss: 11.459011
# [Epoch 28533] Train Loss: 0.761915 | Val Loss: 10.419284
# [Epoch 28534] Train Loss: 0.756128 | Val Loss: 12.190976
# [Epoch 28535] Train Loss: 0.889182 | Val Loss: 10.993611
# [Epoch 28536] Train Loss: 0.861163 | Val Loss: 9.262524
# [Epoch 28537] Train Loss: 0.856076 | Val Loss: 11.011927
# [Epoch 28538] Train Loss: 0.848597 | Val Loss: 12.878237
# [Epoch 28539] Train Loss: 0.849049 | Val Loss: 10.868950
# [Epoch 28540] Train Loss: 0.798563 | Val Loss: 12.986815
# [Epoch 28541] Train Loss: 0.741545 | Val Loss: 9.645718
# [Epoch 28542] Train Loss: 0.843055 | Val Loss: 9.897184
# [Epoch 28543] Train Loss: 0.812536 | Val Loss: 11.867442
# [Epoch 28544] Train Loss: 0.909200 | Val Loss: 11.286771
# [Epoch 28545] Train Loss: 0.794818 | Val Loss: 10.383901
# [Epoch 28546] Train Loss: 0.957206 | Val Loss: 9.349136
# [Epoch 28547] Train Loss: 0.788684 | Val Loss: 9.991766
# [Epoch 28548] Train Loss: 0.825409 | Val Loss: 9.628005
# [Epoch 28549] Train Loss: 0.746706 | Val Loss: 10.735842
# [Epoch 28550] Train Loss: 0.886160 | Val Loss: 8.708775
# [Epoch 28551] Train Loss: 0.938111 | Val Loss: 9.395811
# [Epoch 28552] Train Loss: 0.780778 | Val Loss: 11.107606
# [Epoch 28553] Train Loss: 0.890289 | Val Loss: 10.762679
# [Epoch 28554] Train Loss: 0.828170 | Val Loss: 10.612517
# [Epoch 28555] Train Loss: 0.805362 | Val Loss: 10.385842
# [Epoch 28556] Train Loss: 0.857891 | Val Loss: 11.251284
# [Epoch 28557] Train Loss: 0.806586 | Val Loss: 10.181225
# [Epoch 28558] Train Loss: 1.032791 | Val Loss: 8.561113
# [Epoch 28559] Train Loss: 0.919779 | Val Loss: 12.567291
# [Epoch 28560] Train Loss: 0.808069 | Val Loss: 11.868923
# [Epoch 28561] Train Loss: 0.831411 | Val Loss: 12.849902
# [Epoch 28562] Train Loss: 0.743094 | Val Loss: 9.413744
# [Epoch 28563] Train Loss: 0.712378 | Val Loss: 12.659484
# [Epoch 28564] Train Loss: 0.691011 | Val Loss: 11.247277
# [Epoch 28565] Train Loss: 0.765717 | Val Loss: 9.573788
# [Epoch 28566] Train Loss: 0.778904 | Val Loss: 11.039507
# [Epoch 28567] Train Loss: 0.788010 | Val Loss: 9.411677
# [Epoch 28568] Train Loss: 0.763680 | Val Loss: 10.134464
# [Epoch 28569] Train Loss: 0.807370 | Val Loss: 13.375353
# [Epoch 28570] Train Loss: 0.869664 | Val Loss: 9.342981
# [Epoch 28571] Train Loss: 0.854855 | Val Loss: 9.799776
# [Epoch 28572] Train Loss: 0.837043 | Val Loss: 10.385407
# [Epoch 28573] Train Loss: 0.808557 | Val Loss: 9.252474
# [Epoch 28574] Train Loss: 0.768515 | Val Loss: 10.104133
# [Epoch 28575] Train Loss: 0.824653 | Val Loss: 11.732432
# [Epoch 28576] Train Loss: 0.790849 | Val Loss: 12.114565
# [Epoch 28577] Train Loss: 0.878854 | Val Loss: 11.182008
# [Epoch 28578] Train Loss: 0.891917 | Val Loss: 11.593323
# [Epoch 28579] Train Loss: 0.762795 | Val Loss: 15.373892
# [Epoch 28580] Train Loss: 0.754686 | Val Loss: 10.254168
# [Epoch 28581] Train Loss: 0.744245 | Val Loss: 9.693256
# [Epoch 28582] Train Loss: 0.797516 | Val Loss: 10.031169
# [Epoch 28583] Train Loss: 0.841372 | Val Loss: 10.682662
# [Epoch 28584] Train Loss: 0.894094 | Val Loss: 11.705824
# [Epoch 28585] Train Loss: 0.831774 | Val Loss: 7.466993
# [Epoch 28586] Train Loss: 0.774554 | Val Loss: 9.733292
# [Epoch 28587] Train Loss: 0.748547 | Val Loss: 8.973853
# [Epoch 28588] Train Loss: 0.744804 | Val Loss: 8.730156
# [Epoch 28589] Train Loss: 0.740312 | Val Loss: 9.234805
# [Epoch 28590] Train Loss: 0.814485 | Val Loss: 10.444391
# [Epoch 28591] Train Loss: 0.763465 | Val Loss: 11.444034
# [Epoch 28592] Train Loss: 0.860254 | Val Loss: 9.791029
# [Epoch 28593] Train Loss: 0.832893 | Val Loss: 13.017782
# [Epoch 28594] Train Loss: 0.821439 | Val Loss: 10.799531
# [Epoch 28595] Train Loss: 0.740003 | Val Loss: 8.725926
# [Epoch 28596] Train Loss: 0.744903 | Val Loss: 10.680012
# [Epoch 28597] Train Loss: 0.876208 | Val Loss: 9.664979
# [Epoch 28598] Train Loss: 0.817404 | Val Loss: 10.206465
# [Epoch 28599] Train Loss: 0.776910 | Val Loss: 9.362619
# [Epoch 28600] Train Loss: 0.836276 | Val Loss: 10.257502
# [Epoch 28601] Train Loss: 0.842560 | Val Loss: 10.381397
# [Epoch 28602] Train Loss: 0.949251 | Val Loss: 12.419081
# [Epoch 28603] Train Loss: 0.957877 | Val Loss: 8.782380
# [Epoch 28604] Train Loss: 1.003573 | Val Loss: 10.750778
# [Epoch 28605] Train Loss: 0.844710 | Val Loss: 8.295064
# [Epoch 28606] Train Loss: 0.840365 | Val Loss: 11.439004
# [Epoch 28607] Train Loss: 0.798892 | Val Loss: 12.346249
# [Epoch 28608] Train Loss: 0.737364 | Val Loss: 11.012285
# [Epoch 28609] Train Loss: 0.795495 | Val Loss: 8.477980
# [Epoch 28610] Train Loss: 0.822997 | Val Loss: 7.660473
# [Epoch 28611] Train Loss: 1.110644 | Val Loss: 10.910562
# [Epoch 28612] Train Loss: 1.004578 | Val Loss: 11.615180
# [Epoch 28613] Train Loss: 0.999939 | Val Loss: 11.585935
# [Epoch 28614] Train Loss: 0.901867 | Val Loss: 12.762705
# [Epoch 28615] Train Loss: 0.849655 | Val Loss: 12.152593
# [Epoch 28616] Train Loss: 0.856580 | Val Loss: 10.286603
# [Epoch 28617] Train Loss: 0.869454 | Val Loss: 10.315361
# [Epoch 28618] Train Loss: 0.881583 | Val Loss: 13.050305
# [Epoch 28619] Train Loss: 1.019719 | Val Loss: 9.732034
# [Epoch 28620] Train Loss: 0.992829 | Val Loss: 9.435639
# [Epoch 28621] Train Loss: 0.984702 | Val Loss: 11.513026
# [Epoch 28622] Train Loss: 0.921857 | Val Loss: 10.823433
# [Epoch 28623] Train Loss: 0.820108 | Val Loss: 9.198294
# [Epoch 28624] Train Loss: 0.861277 | Val Loss: 10.807402
# [Epoch 28625] Train Loss: 0.807582 | Val Loss: 10.785062
# [Epoch 28626] Train Loss: 0.777798 | Val Loss: 11.301239
# [Epoch 28627] Train Loss: 0.769428 | Val Loss: 10.226408
# [Epoch 28628] Train Loss: 0.843764 | Val Loss: 12.278706
# [Epoch 28629] Train Loss: 0.790929 | Val Loss: 11.811544
# [Epoch 28630] Train Loss: 0.702916 | Val Loss: 10.107536
# [Epoch 28631] Train Loss: 0.755944 | Val Loss: 11.335404
# [Epoch 28632] Train Loss: 0.832247 | Val Loss: 10.498353
# [Epoch 28633] Train Loss: 0.792944 | Val Loss: 9.807048
# [Epoch 28634] Train Loss: 0.703195 | Val Loss: 10.158488
# [Epoch 28635] Train Loss: 0.760335 | Val Loss: 10.420645
# [Epoch 28636] Train Loss: 0.788650 | Val Loss: 11.153845
# [Epoch 28637] Train Loss: 0.728020 | Val Loss: 11.295478
# [Epoch 28638] Train Loss: 0.798023 | Val Loss: 12.314319
# [Epoch 28639] Train Loss: 0.778871 | Val Loss: 11.671110
# [Epoch 28640] Train Loss: 0.740015 | Val Loss: 10.376854
# [Epoch 28641] Train Loss: 0.715630 | Val Loss: 10.327216
# [Epoch 28642] Train Loss: 0.794409 | Val Loss: 11.338748
# [Epoch 28643] Train Loss: 0.825069 | Val Loss: 11.969134
# [Epoch 28644] Train Loss: 0.729723 | Val Loss: 10.689779
# [Epoch 28645] Train Loss: 0.727375 | Val Loss: 12.531033
# [Epoch 28646] Train Loss: 0.772911 | Val Loss: 9.544030
# [Epoch 28647] Train Loss: 0.722066 | Val Loss: 10.794798
# [Epoch 28648] Train Loss: 0.739736 | Val Loss: 11.333072
# [Epoch 28649] Train Loss: 0.731127 | Val Loss: 11.225466
# [Epoch 28650] Train Loss: 0.737593 | Val Loss: 13.412600
# [Epoch 28651] Train Loss: 0.782716 | Val Loss: 8.578760
# [Epoch 28652] Train Loss: 0.835782 | Val Loss: 10.225685
# [Epoch 28653] Train Loss: 0.875070 | Val Loss: 9.740935
# [Epoch 28654] Train Loss: 0.780744 | Val Loss: 9.679547
# [Epoch 28655] Train Loss: 0.769692 | Val Loss: 11.042451
# [Epoch 28656] Train Loss: 0.934599 | Val Loss: 11.176109
# [Epoch 28657] Train Loss: 0.854158 | Val Loss: 10.364987
# [Epoch 28658] Train Loss: 0.771550 | Val Loss: 11.738648
# [Epoch 28659] Train Loss: 0.802085 | Val Loss: 11.657522
# [Epoch 28660] Train Loss: 0.758072 | Val Loss: 11.654451
# [Epoch 28661] Train Loss: 0.975324 | Val Loss: 10.991265
# [Epoch 28662] Train Loss: 0.881082 | Val Loss: 12.928448
# [Epoch 28663] Train Loss: 0.892796 | Val Loss: 9.301003
# [Epoch 28664] Train Loss: 0.832963 | Val Loss: 9.578481
# [Epoch 28665] Train Loss: 0.758098 | Val Loss: 10.776669
# [Epoch 28666] Train Loss: 0.797077 | Val Loss: 12.307465
# [Epoch 28667] Train Loss: 0.758585 | Val Loss: 12.799887
# [Epoch 28668] Train Loss: 0.749243 | Val Loss: 11.439583
# [Epoch 28669] Train Loss: 0.708008 | Val Loss: 11.099836
# [Epoch 28670] Train Loss: 0.865727 | Val Loss: 10.163903
# [Epoch 28671] Train Loss: 0.785946 | Val Loss: 12.260606
# [Epoch 28672] Train Loss: 0.783107 | Val Loss: 9.900273
# [Epoch 28673] Train Loss: 0.728063 | Val Loss: 9.898563
# [Epoch 28674] Train Loss: 0.758459 | Val Loss: 9.981815
# [Epoch 28675] Train Loss: 0.720763 | Val Loss: 12.191708
# [Epoch 28676] Train Loss: 0.711338 | Val Loss: 12.136821
# [Epoch 28677] Train Loss: 0.811412 | Val Loss: 10.261167
# [Epoch 28678] Train Loss: 0.789919 | Val Loss: 13.046680
# [Epoch 28679] Train Loss: 0.777505 | Val Loss: 9.730065
# [Epoch 28680] Train Loss: 0.795638 | Val Loss: 11.620668
# [Epoch 28681] Train Loss: 0.730520 | Val Loss: 7.790401
# [Epoch 28682] Train Loss: 0.719995 | Val Loss: 10.268446
# [Epoch 28683] Train Loss: 0.728137 | Val Loss: 12.393826
# [Epoch 28684] Train Loss: 0.701904 | Val Loss: 8.953816
# [Epoch 28685] Train Loss: 0.744473 | Val Loss: 10.627110
# [Epoch 28686] Train Loss: 0.775196 | Val Loss: 10.675837
# [Epoch 28687] Train Loss: 0.813939 | Val Loss: 11.221597
# [Epoch 28688] Train Loss: 0.881975 | Val Loss: 11.192150
# [Epoch 28689] Train Loss: 0.867686 | Val Loss: 10.213849
# [Epoch 28690] Train Loss: 0.975988 | Val Loss: 11.174238
# [Epoch 28691] Train Loss: 0.960496 | Val Loss: 10.555797
# [Epoch 28692] Train Loss: 0.922570 | Val Loss: 11.604077
# [Epoch 28693] Train Loss: 1.050751 | Val Loss: 9.458415
# [Epoch 28694] Train Loss: 0.903703 | Val Loss: 8.557128
# [Epoch 28695] Train Loss: 0.894477 | Val Loss: 10.791621
# [Epoch 28696] Train Loss: 0.896934 | Val Loss: 10.382670
# [Epoch 28697] Train Loss: 0.946096 | Val Loss: 11.682037
# [Epoch 28698] Train Loss: 0.891631 | Val Loss: 11.844592
# [Epoch 28699] Train Loss: 0.859027 | Val Loss: 11.600123
# [Epoch 28700] Train Loss: 0.863848 | Val Loss: 11.230280
# [Epoch 28701] Train Loss: 0.793519 | Val Loss: 7.652250
# [Epoch 28702] Train Loss: 0.760028 | Val Loss: 10.805774
# [Epoch 28703] Train Loss: 0.740573 | Val Loss: 9.703980
# [Epoch 28704] Train Loss: 0.764349 | Val Loss: 11.051585
# [Epoch 28705] Train Loss: 0.791700 | Val Loss: 8.616425
# [Epoch 28706] Train Loss: 0.824527 | Val Loss: 11.108869
# [Epoch 28707] Train Loss: 0.770278 | Val Loss: 8.859841
# [Epoch 28708] Train Loss: 0.711314 | Val Loss: 12.106533
# [Epoch 28709] Train Loss: 0.748052 | Val Loss: 12.372155
# [Epoch 28710] Train Loss: 0.812424 | Val Loss: 11.706960
# [Epoch 28711] Train Loss: 0.838196 | Val Loss: 10.824327
# [Epoch 28712] Train Loss: 0.777328 | Val Loss: 10.165859
# [Epoch 28713] Train Loss: 0.772371 | Val Loss: 11.041930
# [Epoch 28714] Train Loss: 0.849829 | Val Loss: 9.892389
# [Epoch 28715] Train Loss: 0.897328 | Val Loss: 11.077637
# [Epoch 28716] Train Loss: 0.878564 | Val Loss: 10.384353
# [Epoch 28717] Train Loss: 0.792258 | Val Loss: 11.830205
# [Epoch 28718] Train Loss: 0.764662 | Val Loss: 11.587918
# [Epoch 28719] Train Loss: 0.911490 | Val Loss: 8.553354
# [Epoch 28720] Train Loss: 0.902544 | Val Loss: 12.681905
# [Epoch 28721] Train Loss: 0.851129 | Val Loss: 12.811768
# [Epoch 28722] Train Loss: 0.795431 | Val Loss: 9.350917
# [Epoch 28723] Train Loss: 0.785976 | Val Loss: 13.155627
# [Epoch 28724] Train Loss: 0.734624 | Val Loss: 11.110599
# [Epoch 28725] Train Loss: 0.749384 | Val Loss: 11.109426
# [Epoch 28726] Train Loss: 0.863414 | Val Loss: 8.885084
# [Epoch 28727] Train Loss: 0.744567 | Val Loss: 8.664114
# [Epoch 28728] Train Loss: 0.750637 | Val Loss: 10.438122
# [Epoch 28729] Train Loss: 0.719724 | Val Loss: 9.905528
# [Epoch 28730] Train Loss: 0.663961 | Val Loss: 10.086920
# [Epoch 28731] Train Loss: 0.725947 | Val Loss: 11.779286
# [Epoch 28732] Train Loss: 0.712497 | Val Loss: 11.828345
# [Epoch 28733] Train Loss: 0.866728 | Val Loss: 11.315920
# [Epoch 28734] Train Loss: 0.900270 | Val Loss: 10.977032
# [Epoch 28735] Train Loss: 0.829119 | Val Loss: 10.723686
# [Epoch 28736] Train Loss: 0.855992 | Val Loss: 10.381095
# [Epoch 28737] Train Loss: 0.777652 | Val Loss: 10.697210

# %% [markdown]
# ### Inference and visualizations for this run

# %%
# --- 2.10 Final, Unbiased Evaluation on the TRUE Test Set ---
print("\nPerforming final, unbiased evaluation on the held-out test set...")
NUM_TEST_SAMPLES_TO_PLOT = 4
NUM_POSTERIOR_SAMPLES = 100

fig_results, axes = plt.subplots(NUM_TEST_SAMPLES_TO_PLOT, 1, figsize=(10, 5 * NUM_TEST_SAMPLES_TO_PLOT), sharex=True)
if NUM_TEST_SAMPLES_TO_PLOT == 1: axes = [axes]

plot_indices = np.random.choice(len(u0_test_np), NUM_TEST_SAMPLES_TO_PLOT, replace=False)

for i, ax in zip(plot_indices, axes):
    # Now we use the true test data for plotting
    y_condition_np = u_test_np[i]
    x_ground_truth_np = u0_test_np[i]
    
    y_condition_scaled_np = y_scaler.transform(y_condition_np.reshape(1, -1))
    y_condition_tensor = torch.from_numpy(y_condition_scaled_np).float().to(device)
    
    posterior_samples_scaled = conditional_sampler(
        score_model, marginal_prob_std, diffusion_coeff, y_condition_tensor,
        NUM_POSTERIOR_SAMPLES, X_DIM, num_steps=2000, device=device # Use more steps for final quality
    )
    
    posterior_samples_np = x_scaler.inverse_transform(posterior_samples_scaled.cpu().numpy())
    posterior_mean = np.mean(posterior_samples_np, axis=0)
    posterior_std = np.std(posterior_samples_np, axis=0)
    
    # ... (Plotting logic remains the same)
    ax.plot(x_coords, y_condition_np, 'k:', linewidth=2, label='$u(x,T)$ (Given Condition)')
    ax.plot(x_coords, x_ground_truth_np, 'g-', linewidth=2, label='$u(x,0)$ (Ground Truth)')
    ax.plot(x_coords, posterior_mean, 'r--', linewidth=2, label='Posterior Mean Prediction')
    ax.fill_between(
        x_coords, posterior_mean - 2 * posterior_std, posterior_mean + 2 * posterior_std,
        color='r', alpha=0.2, label='Posterior Uncertainty ($\pm 2\sigma$)'
    )
    ax.set_title(f"True Test Sample (Original Index #{test_non_zero_indices[i]})")
    ax.set_ylabel("u(x)")
    ax.legend()
    ax.grid(True, linestyle='--')

axes[-1].set_xlabel("x")
plt.tight_layout()
fig_results.savefig('final_unbiased_test_results2.png')
print("Inference finished. Final results plot saved to 'final_unbiased_test_results.png'.")
plt.show()
# Out:
# Performing final, unbiased evaluation on the held-out test set...
# Conditional Sampling:   0%|          | 0/2000 [00:00<?, ?it/s]
# Conditional Sampling:   0%|          | 0/2000 [00:00<?, ?it/s]
# Conditional Sampling:   0%|          | 0/2000 [00:00<?, ?it/s]
# Conditional Sampling:   0%|          | 0/2000 [00:00<?, ?it/s]
# Inference finished. Final results plot saved to 'final_unbiased_test_results.png'.

# %% [markdown]
# ### Inference from loaded model(checkpoint)

# %%
# ==========================================================================================
# PART 3: Standalone Inference and Visualization Cell
# ==========================================================================================

# --- 3.1 Setup Environment ---
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
MODEL_SAVE_PATH = 'best_score_model_checkpoint.pth'
# MODEL_SAVE_PATH = 'results/epoch40000_batch1024_CNN_TooSmooth/best_score_model_checkpoint.pth'
print(f"Using device: {device} for inference.")

# --- 3.2 Load the Complete Checkpoint ---
print(f"Loading model and configuration from {MODEL_SAVE_PATH}...")
try:
    checkpoint = torch.load(MODEL_SAVE_PATH, map_location=device, weights_only=False)
except FileNotFoundError:
    print(f"Error: Checkpoint file not found at {MODEL_SAVE_PATH}. Please run the training cell first.")
    exit()

# --- 3.3 Recreate All Components from the Checkpoint ---

# a) Recreate SDE functions from saved hyperparameters
loaded_sde_params = checkpoint['sde_hyperparams']
marginal_prob_std = functools.partial(marginal_prob_std_fn, **loaded_sde_params)
diffusion_coeff = functools.partial(diffusion_coeff_fn, **loaded_sde_params)
print("SDE functions recreated.")

# b) Recreate and load states for data scalers
loaded_scaler_states = checkpoint['scaler_states']
x_scaler = SimpleScaler().load_state(loaded_scaler_states['x_scaler'])
y_scaler = SimpleScaler().load_state(loaded_scaler_states['y_scaler'])
print("Data scalers recreated.")

# c) Recreate Model and load weights
loaded_model_params = checkpoint['model_hyperparams']
# !!! make sure the NN architecture is consistent !!!
# inference_model = ConditionalScoreNet(marginal_prob_std, **loaded_model_params).to(device)
inference_model = ConditionalConv1DScoreNet(marginal_prob_std, **loaded_model_params).to(device)
inference_model.load_state_dict(checkpoint['model_state_dict'])
inference_model.eval() # Set model to evaluation mode
print("Model architecture recreated and weights loaded successfully.")

# --- 3.4 Perform Final, Unbiased Evaluation on the TRUE Test Set ---

# Load the necessary raw data for inference and plotting
x_coords = np.load('x.npy')
u0_test_np_raw = np.load('u0_test_data.npy')
u_test_np_raw = np.load('u_test_data.npy')

# Filter the test data just as in training to ensure consistency
test_non_zero_indices = [idx for idx, s in enumerate(u0_test_np_raw) if np.max(np.abs(s)) > 1e-6]
u0_test_np = u0_test_np_raw[test_non_zero_indices]
u_test_np = u_test_np_raw[test_non_zero_indices]

print(f"\nPerforming inference on the filtered test set of size {len(u0_test_np)}...")
NUM_TEST_SAMPLES_TO_PLOT = 4
NUM_POSTERIOR_SAMPLES = 100

fig_results, axes = plt.subplots(NUM_TEST_SAMPLES_TO_PLOT, 1, figsize=(10, 5 * NUM_TEST_SAMPLES_TO_PLOT), sharex=True)
if NUM_TEST_SAMPLES_TO_PLOT == 1: axes = [axes]

# Define sampler_params for the inference call
sampler_params = {
    'marginal_prob_std': marginal_prob_std,
    'diffusion_coeff': diffusion_coeff,
    'x_dim': loaded_model_params['x_dim'],
    'num_steps': 2000, # Using more steps for final high-quality results
    'device': device
}

# Randomly select indices from the filtered test set for plotting
plot_indices = np.random.choice(len(u0_test_np), NUM_TEST_SAMPLES_TO_PLOT, replace=False)

for i, ax in zip(plot_indices, axes):
    y_condition_np = u_test_np[i]
    x_ground_truth_np = u0_test_np[i]
    
    # Scale the condition using the loaded scaler
    y_condition_scaled_np = y_scaler.transform(y_condition_np.reshape(1, -1))
    y_condition_tensor = torch.from_numpy(y_condition_scaled_np).float().to(device)
    
    # Generate samples using the loaded model
    posterior_samples_scaled = conditional_sampler(
        inference_model,
        **sampler_params,
        y_cond=y_condition_tensor,
        batch_size=NUM_POSTERIOR_SAMPLES
    )
    
    # Inverse-transform the generated samples to the original data scale
    posterior_samples_np = x_scaler.inverse_transform(posterior_samples_scaled.cpu().numpy())
    
    # Calculate statistics and plot
    posterior_mean = np.mean(posterior_samples_np, axis=0)
    posterior_std = np.std(posterior_samples_np, axis=0)
    
    ax.plot(x_coords, y_condition_np, 'k:', linewidth=2, label='$u(x,T)$ (Given Condition)')
    ax.plot(x_coords, x_ground_truth_np, 'g-', linewidth=2, label='$u(x,0)$ (Ground Truth)')
    ax.plot(x_coords, posterior_mean, 'r--', linewidth=2, label='Posterior Mean Prediction')
    ax.fill_between(
        x_coords, posterior_mean - 2 * posterior_std, posterior_mean + 2 * posterior_std,
        color='r', alpha=0.2, label='Posterior Uncertainty ($\pm 2\sigma$)'
    )
    ax.set_title(f"Random Test Sample (Original Index #{test_non_zero_indices[i]})")
    ax.set_ylabel("u(x)")
    ax.legend()
    ax.grid(True, linestyle='--')

axes[-1].set_xlabel("x")
plt.tight_layout()
fig_results.savefig('final_unbiased_test_results.png')
print("Inference finished. Final results plot saved to 'final_unbiased_test_results.png'.")
plt.show()
# Out:
# Using device: cuda for inference.
# Loading model and configuration from best_score_model_checkpoint.pth...
# SDE functions recreated.
# Data scalers recreated.
# Model architecture recreated and weights loaded successfully.
#
# Performing inference on the filtered test set of size 100...
# Conditional Sampling:   0%|          | 0/2000 [00:00<?, ?it/s]
# Conditional Sampling:   0%|          | 0/2000 [00:00<?, ?it/s]
# Conditional Sampling:   0%|          | 0/2000 [00:00<?, ?it/s]
# Conditional Sampling:   0%|          | 0/2000 [00:00<?, ?it/s]
# Inference finished. Final results plot saved to 'final_unbiased_test_results.png'.
